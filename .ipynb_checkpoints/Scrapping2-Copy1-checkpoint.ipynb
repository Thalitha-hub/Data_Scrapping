# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import time

# Path to the Microsoft Edge WebDriver executable
# driver_path = "/path/to/msedgedriver"
# Create a new instance of Microsoft Edge
driver = webdriver.Edge()

# Visit the dynamic website
driver.get("https://www.lifeverde.de/gruene-unternehmen/nachhaltige-mode")

# Scroll down to load more content
# Adjust the number of iterations based on the page's structure
for _ in range(25):
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(5)  # Wait for the content to load, you can adjust the delay if needed

# Get the page source code after the website has fully loaded
html = driver.page_source

# Close the browser
driver.quit()

# Parse the HTML using BeautifulSoup
soup = BeautifulSoup(html, "html.parser")

# Find all the links with class "firmenname"
links = []  # List to store the extracted links
for link in soup.find_all('a', class_='firmenname'):  # Specify the desired class attribute
    href = link.get('href')
    links.append(href)
# # Print the links
# for link in links:
#     print(link["href"])

# %%
# !pip install selenium

# %%
len(links)
# Out:
# 340

# %%
company_data = []
for link in links:
    driver = webdriver.Edge()

    # Visit the website
    driver.get(link)

    # Get the page source code after the website has fully loaded
    html = driver.page_source

    # Close the browser
    driver.quit()

    # Parse the HTML using BeautifulSoup
    soup = BeautifulSoup(html, "html.parser")

    # Find the name and email within the div with class "adressbox"
    adressbox_div = soup.find("div", class_="adressbox")

    # Find the name within the adressbox div
    name_element = adressbox_div.find("strong")
    name = name_element.text.strip() if name_element else "Name not found"

    # Find the email within the adressbox div
    email_element = adressbox_div.find("a")
    email = email_element.text.strip() if email_element else "Email not found"
    
    data = {}
    data['Name'] = name
    data['Email'] = email
    company_data.append(data)

    print(data)
# Out:
# {'Name': 'Cantana                            GmbH', 'Email': 'info@cantana.com'}
# {'Name': 'nice to meet me                            OG', 'Email': 'mail@nicetomeetme.at'}
# {'Name': 'vervola                            GmbH', 'Email': 'susanne@vervola.com'}
# {'Name': 'neu.land                            GmbH', 'Email': 'hello@elamo.me'}
# {'Name': 'Celtic & Co.                            Ltd', 'Email': 'kathrin.barnes@celticandco.com'}
# {'Name': 'We Are Knitters                            SL', 'Email': 'sabrina@weareknitters.com'}
# {'Name': 'This Is Vegan - Plantbased Lifestyle Magazin                            Einzelunternehmen', 'Email': 'info@this-is-vegan.com'}
# {'Name': 'ila·ila | FAIR CONCEPT STORE                            GmbH', 'Email': 'info@ilaila.de'}
# {'Name': 'VorReiter                            Einzelunternehmen', 'Email': 'isabel.salecker@vorreiter-reitsport.de'}
# {'Name': 'URBN STDIOS                            AG', 'Email': 'hello@urbnc3.com'}
# {'Name': 'Fair Couture                            Einzelunternehmer', 'Email': 'mail@faircouture.com'}
# {'Name': 'Nordgreen                             Aps', 'Email': 'hallo@nordgreen.com'}
# {'Name': 'Barn Bux                            Einzelunternehmen', 'Email': 'info@barnbux.de'}
# {'Name': 'Lunettes Selection                            Einzelunternehmen', 'Email': 'info@lunettes-selection.de'}
# {'Name': 'Boob Design                            GmbH', 'Email': 'shop@boobdesign.com'}
# {'Name': 'ecodog®                            Einzelunternehmen', 'Email': 'nicole.kraft@ecodog.de'}
# {'Name': 'Yvonne Mankel Jewellery • Nachhaltiger Schmuck & Trauringe                            Einzelunternehmen', 'Email': 'info@yvonnemankel.de'}
# {'Name': 'Baron Filou                            GmbH', 'Email': 'office@baronfilou.com'}
# {'Name': 'Spirit of Island                            Einzelunternehmen', 'Email': 'friends@spiritofisland.de'}
# {'Name': 'OH OH OM ethical sportswear                            Einzelunternehmen', 'Email': 'ethicalsportswear@ohohom.com'}
# {'Name': 'Elkline                            GmbH', 'Email': 'customerservice@elkline.de'}
# {'Name': 'GOT BAG                            GmbH', 'Email': 'hello@got-bag.com'}
# {'Name': 'B KREB jewelry                            Einzelunternehmen', 'Email': 'mail@bkreb.com'}
# {'Name': 'Unterwegs Outdoor Shop                            GmbH', 'Email': 'shop@unterwegs.biz'}
# {'Name': 'Shop Like You Give a Damn                            B.V.', 'Email': 'info@shoplikeyougiveadamn.com'}
# {'Name': 'Kulson                            GmbH', 'Email': 'info@kulson.de'}
# {'Name': 'Wildling Shoes                            GmbH', 'Email': 'https://www.wildling.shoes/pages/kontakt'}
# {'Name': 'Fair Affairs                            GmbH', 'Email': 'rainer@my-fair-affair.com'}
# {'Name': 'Felidae (Europe)                            GmbH', 'Email': 'hello@kattbjoern.de'}
# {'Name': 'Levensgaarn                              Andrea Sauer', 'Email': 'info@levensgaarn.de'}
# {'Name': 'Reciclage                            Einzelunternehmen', 'Email': 'info@reciclage.de'}
# {'Name': 'STAMPS                            GmbH', 'Email': 'info@stamps.eu'}
# {'Name': 'Feelgrounds                            Ltd', 'Email': 'info@feelgrounds.com'}
# {'Name': 'New Systems                            GmbH', 'Email': 'service@selenacare.com'}
# {'Name': 'Souleway                            GmbH', 'Email': 'hello@souleway.com'}
# {'Name': 'Gebrüder Haasis                            GmbH & Co. KG', 'Email': 'admin@haasis-bodywear.de'}
# {'Name': 'Nordlicht Naturtextilien                            GmbH', 'Email': 'mail@nordlichtstore.com'}
# {'Name': 'dayê rose                            UG (haftungsbeschränkt) & Co. KG', 'Email': 'sermin@dayerose.com'}
# {'Name': 'Maren Jewellery                            Einzelunternehmen', 'Email': 'helge@marenjewellery.com'}
# {'Name': 'Schwabenpower                            c/o MTS Schrode AG', 'Email': 'team@schwabenpower.de'}
# {'Name': 'ocean-wear                            Einzelunternehmer', 'Email': 'o.icli@ocean-wear.store'}
# {'Name': 'Trauringmanufaktur                            Einzelunternehmen', 'Email': 'info@trauringmanufaktur.de'}
# {'Name': 'Kristin Elm                             Einzelunternehmen', 'Email': 'info@kristinelm.com'}
# {'Name': 'greenyogashop                            GmbH', 'Email': 'info@greenyogashop.com'}
# {'Name': 'AMANA Beachwear                            KLG', 'Email': 'info@amanabeachwear.com'}
# {'Name': 'Nordic Flow                            GmbH & Co. KG', 'Email': 'namaste@chakrana.world'}
# {'Name': 'Modibodi                            Limited', 'Email': 'info@modibodi.com'}
# {'Name': 'RADIAN                            Design', 'Email': 'contact@radian-design.com'}
# {'Name': 'Bon + Berg                            Bon and Berg Ltd', 'Email': 'hello@bonandberg.com'}
# {'Name': 'changemaking.now                            Einzelunternehmen', 'Email': 'info@changemakingnow.com'}
# {'Name': 'Tiny Wild Hearts                             e.U.', 'Email': 'office@tinywildhearts.com'}
# {'Name': 'VOLANS Swimwear                            GmbH', 'Email': 'info@volans.ch'}
# {'Name': 'modabilé                            OHG', 'Email': 'info@modabile.de'}
# {'Name': 'Jojeco                            GmbH', 'Email': 'shop@jojeco.de'}
# {'Name': 'RH Royal Horsemen                            GmbH', 'Email': 'info@royalhorsemen.de'}
# {'Name': 'Pikfine                            GmbH', 'Email': 'service@pikfine.de'}
# {'Name': 'Awearable                            GmbH', 'Email': 'contact@awearable.eu'}
# {'Name': 'Sanna Lindström                            GmbH', 'Email': 'hej@sannalindstroem.de'}
# {'Name': 'Givn Berlin                            Stoffbruch Fair Fashion GmbH', 'Email': 'info@givnberlin.com'}
# {'Name': 'toolly                            Einzelunternehmen', 'Email': 'tomo@toolly.de'}
# {'Name': 'Marin et Marine                             GBR', 'Email': 'hello@marinetmarine.com'}
# {'Name': 'Jurtenleder                            UG', 'Email': 'info@jurtenleder.com'}
# {'Name': 'Pantolinos Manufaktur                             GmbH', 'Email': 'info@pantolinos.de'}
# {'Name': 'Lila Lämmchen                            GmbH', 'Email': 'service@lilalaemmchen-shop.de'}
# {'Name': 'Engel                            GmbH', 'Email': 'info@engel-natur.de'}
# {'Name': 'KATTUN-Stoffe.de                            Einzelunternehmen', 'Email': 'info@kattun-stoffe.de'}
# {'Name': 'Naturzwerge Kindermode                            Einzelunternehmen', 'Email': 'info@naturzwerge-kindermode.de'}
# {'Name': 'Cottonbudbaby                            Relenda GmbH', 'Email': 'service@cottonbudbaby.com'}
# {'Name': 'petit cochon Manufaktur                             GmbH', 'Email': 'kontakt@petit-co.com'}
# {'Name': 'Hug & Grow                            e. K.', 'Email': 'hallo@hug-and-grow.de'}
# {'Name': 'Wecando Group Großhandels                            GmbH', 'Email': 'mail@vuelove-shop.de'}
# {'Name': 'Orbasics                            GmbH', 'Email': 'hi@orbasics.com'}
# {'Name': 'Kalima                            Einzelunternehmen', 'Email': 'info@kalima-design.de'}
# {'Name': 'm23 sports & fashion                            UG (haftungsbeschränkt)', 'Email': 'info@m23.store'}
# {'Name': 'pos.sei.mo Marianne Birkenfeld                            Einzelfirma', 'Email': 'info@posseimo.de'}
# {'Name': 'QWSTION                            AG', 'Email': 'wecare@qwstion.com'}
# {'Name': 'Living Crafts                            GmbH & Co. KG', 'Email': 'info@livingcrafts.de'}
# {'Name': 'Rheinufer                            e.K.', 'Email': 'service@rheinufer.net'}
# {'Name': 'Vegamina                            Einzelunternehmen', 'Email': 'info@vegamina.de'}
# {'Name': 'fairtragen                            GmbH', 'Email': 'kontakt@fairtragen.de'}
# {'Name': 'dedics                            UG', 'Email': 'info@evidend.de'}
# {'Name': 'Spangeltangel (Peggy Albrecht Diplomdesignerin)                            Einzelunternehmen', 'Email': 'info@spangeltangel.de'}
# {'Name': 'SALZWASSER                            GmbH', 'Email': 'info@salzwasser.eu'}
# {'Name': 'TRANQUILLO                            GmbH', 'Email': 'info@tranquillo-shop.de'}
# {'Name': 'MONTREET                            EPU', 'Email': 'office@montreet.net'}
# {'Name': 'Kiglu                             GmbH', 'Email': 'hallo@kiglu.de'}
# {'Name': 'anlovia-oh so wooly                            einzelunternehmen', 'Email': 'info@anlovia-wolle.de'}
# {'Name': 'Kaipara - Merino Sportswear                            GmbH', 'Email': 'info@kaipara.de'}
# {'Name': 'Kultgut                            GbR', 'Email': 'kultgut@mail.de'}
# {'Name': 'GIRO - LIVE FOR THIS                            GmbH', 'Email': 'info@giro-sports.com'}
# {'Name': 'WeeDo funwear GmbH                            GmbH', 'Email': 'sales@weedo.de'}
# {'Name': 'Waschbär GmbH                            GmbH', 'Email': 'kundenservice@waschbaer.de'}
# {'Name': 'NOAH - Italian Vegan Shoes                            Einzelunternehmer', 'Email': 'contact@noah-shop.com'}
# {'Name': 'WeltPartner eG                            eingetragene Genossenschaft', 'Email': 'info@weltpartner.de'}
# {'Name': 'ALPIN LOACKER GmbH                            GmbH', 'Email': 'felix@alpinloacker.at'}
# {'Name': 'Kulmine                            e. K.', 'Email': 'post@kulmine.de'}
# {'Name': 'Wollstube am Lesumer Bahnhof                            Einzelhandel', 'Email': 'janssen@wollstube-bremen.de'}
# {'Name': 'Stadelmann Natur                            GbR', 'Email': 'info@stadelmann-natur.de'}
# {'Name': 'MIRRORMONKEY                            Einzelunternehmen', 'Email': 'mail@mirror-monkey.de'}
# {'Name': 'MyJama                            Einzelunternehmen', 'Email': 'info@myjama.de'}
# {'Name': 'Doghammer                             GmbH', 'Email': 'team@doghammer.de'}
# {'Name': 'Sterntaler                            GmbH', 'Email': 'service@sterntaler.com'}
# {'Name': 'Dillysocks                            AG', 'Email': 'contact@dillysocks.com'}
# {'Name': 'iQ Company                            AG', 'Email': 'info@iq-uv.com'}
# {'Name': 'Carney                            GmbH & Co. KG', 'Email': 'info@orangenkinder.de'}
# {'Name': 'soleash                            e.U.', 'Email': 'kontakt@soleash.com'}
# {'Name': 'Barbara Betz & Volker Prößdorf                             GbR', 'Email': 'info@magadi.de'}
# {'Name': 'HULKER EUROPE DISTRIBUTION                            s.r.o.', 'Email': 'info@ragwear.com'}
# {'Name': 'maesh                             Gmbh', 'Email': 'hellol@maesh.de'}
# {'Name': 'LANIUS                            GmbH', 'Email': 'shop@lanius.com'}
# {'Name': 'vierfreunde                            GmbH', 'Email': 'fraguns@kerbholz.com'}
# {'Name': 'Mey                            GmbH & Co. KG', 'Email': 'info@mey.com'}
# {'Name': 'Wichtelkidz                            Einzelunternehmen', 'Email': 'info@wichtelkidz.de'}
# {'Name': 'Sole Runner                            Einzelunternehmen', 'Email': 'info@sole-runner.com'}
# {'Name': 'VON KRONBERG                            KG', 'Email': 'info@von-kronberg.com'}
# {'Name': 'GOOD WILHELM - Clemens Burkert                            Einzelunternehmen', 'Email': 'mail@goodwilhelm.com'}
# {'Name': 'bijoo Kautschuk Schmuck                            Einzelunternehmer', 'Email': 'michael.niedermoser@gmail.com'}
# {'Name': 'simply love it.                            Einzelunternehmen', 'Email': 'jule@simplyloveit.de'}
# {'Name': 'Avocado Store GmbH                            GmbH', 'Email': 'info@avocadostore.de'}
# {'Name': 'anmila sportswear', 'Email': 'contact@anmila.de'}
# {'Name': 'hessnatur                            Hess Natur-Textilien GmbH', 'Email': 'dialog@hess-natur.de'}
# {'Name': 'pure-tex                            GmbH', 'Email': 'mail@pure-pure.de'}
# {'Name': 'promavis - BIObay.de                            GmbH', 'Email': 'info@biobay.de'}
# {'Name': 'entire stories                             GmbH', 'Email': 'elena@entire-stories.com'}
# {'Name': 'Lilienthal Berlin                            GmbH', 'Email': 'press@lilienthal.berlin'}
# {'Name': 'lille mus                            Einzelunternehmen von Lara Fischer', 'Email': 'hej@lille-mus.de'}
# {'Name': 'moekafashion                            Einzelunternehmen', 'Email': 'info.moekafashion@gmail.com'}
# {'Name': 'CONTIGO Fairtrade                            GmbH', 'Email': 'info@contigo.de'}
# {'Name': 'bleed clothing                            GmbH', 'Email': 'info@bleed-clothing.com'}
# {'Name': 'Many Mornings                            Adrian Morawiak, Maciej Butkowski sp. k.', 'Email': 'hello@manymornings.com'}
# {'Name': 'Secrid                            B.V.', 'Email': 'info@secrid.com'}
# {'Name': 'Crawl & Clay                            GmbH', 'Email': 'info@crawlandclay.com'}
# {'Name': 'SURU STUDIOS®                            created by Colombus Textilvertrieb GmbH', 'Email': 'info@surustudios.com'}
# {'Name': 'DETTO FATTO                            Bay City Textilhandels GmbH', 'Email': 'dettofatto-shop@fashioncenter.net'}
# {'Name': 'Senmotic 1.0                            OHG', 'Email': 'info@senmotic-shoes.eu'}
# {'Name': 'MOANINA                            Einzelunternehmen', 'Email': 'kontakt@moanina.com'}
# {'Name': 'VIDAR Sport                            GmbH', 'Email': 'team@vidar-sport.de'}
# {'Name': 'WOTE                            GmbH', 'Email': 'hello@the-wote.com'}
# {'Name': 'littlegreenie                            OHG', 'Email': 'info@littlegreenie.de'}
# {'Name': 'Clockwood - Sven Erik Stando                            Einzelunternehmung', 'Email': 'sven@clockwood.net'}
# {'Name': 'Green Cotton Group Germany                             GmbH', 'Email': 'info@bygreencotton.de'}
# {'Name': 'Le Shop Vegan                            LSV GmbH', 'Email': 'info@leshopvegan.de'}
# {'Name': 'WAYKS                            / Lefas Fashion GmbH', 'Email': 'hellowayks.com'}
# {'Name': 'PureKidz                            Einzelunternehmen', 'Email': 'info@purekidz.de'}
# {'Name': 'KONTOR 1710                            ac.concept GmbH & Co. KG', 'Email': 'info@kontor1710.de'}
# {'Name': 'fuxandfriends                            Einzelunternehmen', 'Email': 'info@fuxandfriends.de'}
# {'Name': 'Antonia Berndt & Julia Meinert                            GbR', 'Email': 'info@antoniaberndt.de'}
# {'Name': 'ZIMMER Fahrradtaschen                            RAFU + ZIMMER OHG', 'Email': 'mail@zimmer-taschen.de'}
# {'Name': 'AIRPAQ                            GmbH', 'Email': 'presse@airpaq.de'}
# {'Name': 'avesu                            GmbH', 'Email': 'avesu@avesu.de'}
# {'Name': 'ConvenientStyle                            Einzelunternehmen', 'Email': 'info@convenientstyle.de'}
# {'Name': 'Samarali                            GmbH', 'Email': 'info@samarali.eu'}
# {'Name': 'lindegger. KUESS die BRAUT                            GmbH', 'Email': 'mail@kuessdiebraut.de'}
# {'Name': 'melovely                            GmbH & Co. KG', 'Email': 'office@melovely.de'}
# {'Name': 'Designmob                            Verein in Gründung', 'Email': 'kontakt@designmob.de'}
# {'Name': 'Ambiletics                            GmbH', 'Email': 'hello@ambiletics.com'}
# {'Name': 'Lebenskleidung                            GbR', 'Email': 'info@lebenskleidung.com'}
# {'Name': 'Dear Darling Berlin                            Einzelunternehmen', 'Email': 'hallo@deardarling.berlin'}
# {'Name': 'Picopoc                            Einzelunternehmen', 'Email': 'info@picopoc.com'}
# {'Name': 'Hirschkind                            supermarché Fair Fashion GmbH', 'Email': 'info@hirschkind.de'}
# {'Name': 'supermarché Fair Fashion                            GmbH', 'Email': 'info@supermarche-berlin.de'}
# {'Name': 'vincente®                            Einzelunternehmen', 'Email': 'info@vincente.de'}
# {'Name': 'Biostoffe-Berlin by Julie Cocon                            Einzelunternehmen', 'Email': 'info@juliecocon.de'}
# {'Name': 'SNUGATA organic kidswear                            Einzelunternehmerin', 'Email': 'post@snugata.de'}
# {'Name': 'WiDDA - Sabine Kelle                            Einzelunternehmen', 'Email': 'info@widda-berlin.de'}
# {'Name': 'Lasalina                            Einzelunternehmen', 'Email': 'mail@lasalina.de'}
# {'Name': 'LOVECO                            GmbH', 'Email': 'hello@loveco-shop.de'}
# {'Name': 'The Fair Cottage                            Einzelhandeln', 'Email': 'info@thefaircottage.com'}
# {'Name': 'kula                            Einzelunternehmen', 'Email': 'info@kula.shoes'}
# {'Name': 'ORONDA Fair Trade Goldschmiede ....                            Stefanie Holtz und Jürgen Krause GbR', 'Email': 'post@oronda.de'}
# {'Name': 't7berlin                            Einzelkauffrau', 'Email': 'lp@t7berlin.com'}
# {'Name': 'Suit For Good                            BABAKOTO UG', 'Email': 'hello@suitsforgood.com'}
# {'Name': 'CharLe - sustainable kids fashion                            Einzelunternehmen', 'Email': 'info@charle-berlin.de'}
# {'Name': 'CARBASA - Segeltuchtaschen                            Personengesellschaft', 'Email': 'info@carbasa.com'}
# {'Name': 'HUMANA Kleidersammlung                            GmbH', 'Email': 'info@humana-kleidersammlung.de'}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 21
#      18 adressbox_div = soup.find("div", class_="adressbox")
#      20 # Find the name within the adressbox div
# ---> 21 name_element = adressbox_div.find("strong")
#      22 name = name_element.text.strip() if name_element else "Name not found"
#      24 # Find the email within the adressbox div
#
# AttributeError: 'NoneType' object has no attribute 'find'

# %%
len(company_data)
# Out:
# 175

# %%
data = pd.DataFrame(company_data)

# %%
data
# Out:
#                                                   Name  \
# 0              Cantana                            GmbH
# 1        nice to meet me                            OG
# 2              vervola                            GmbH
# 3             neu.land                            GmbH
# 4          Celtic & Co.                            Ltd
# ..                                                 ...
# 170  t7berlin                            Einzelkauf...
# 171  Suit For Good                            BABAK...
# 172  CharLe - sustainable kids fashion             ...
# 173  CARBASA - Segeltuchtaschen                    ...
# 174  HUMANA Kleidersammlung                        ...
#
#                               Email
# 0                  info@cantana.com
# 1              mail@nicetomeetme.at
# 2               susanne@vervola.com
# 3                    hello@elamo.me
# 4    kathrin.barnes@celticandco.com
# ..                              ...
# 170                 lp@t7berlin.com
# 171          hello@suitsforgood.com
# 172           info@charle-berlin.de
# 173                info@carbasa.com
# 174  info@humana-kleidersammlung.de
#
# [175 rows x 2 columns]

# %%
links1=links[176:341]

# %%
company_data1 = []
for link in links1:
    driver = webdriver.Edge()

    # Visit the website
    driver.get(link)

    # Get the page source code after the website has fully loaded
    html = driver.page_source

    # Close the browser
    driver.quit()

    # Parse the HTML using BeautifulSoup
    soup = BeautifulSoup(html, "html.parser")

    # Find the name and email within the div with class "adressbox"
    adressbox_div = soup.find("div", class_="adressbox")

    # Find the name within the adressbox div
    name_element = adressbox_div.find("strong")
    name = name_element.text.strip() if name_element else "Name not found"

    # Find the email within the adressbox div
    email_element = adressbox_div.find("a")
    email = email_element.text.strip() if email_element else "Email not found"
    
    data = {}
    data['Name'] = name
    data['Email'] = email
    company_data1.append(data)

    print(data)
# Out:
# {'Name': 'Bonjour Sérénité                            Einzelunternehmen', 'Email': 'bonjour@bonjourserenite.com'}
# {'Name': 'Schelchen                            GmbH', 'Email': 'info@pedag.de'}
# {'Name': 'Frija Omina                            Einzelunternehmen', 'Email': 'mail@frija-omina.com'}
# {'Name': 'slowli                            - Fair Fashion', 'Email': 'hey@slowli.de'}
# {'Name': 'Deepmello                            UG', 'Email': 'info@deepmello.de'}
# {'Name': 'Greenbomb                            Ethifashion GmbH', 'Email': 'info@greenbomb.de'}
# {'Name': 'Mrs.Hippie                            GmbH', 'Email': 'knauschner@geh-bunt.de'}
# {'Name': 'little kiwi                            Einzelunternehmer', 'Email': 'info@little-kiwi.de'}
# {'Name': 'hukkepack                            Einzelhandel', 'Email': 'hallo@hukkepack.de'}
# {'Name': 'karlskopf                            UG (haftungsbeschränkt)', 'Email': 'info@karlskopf.net'}
# {'Name': 'Jill Green                            GmbH', 'Email': 'info@jillgreen.com'}
# {'Name': '2Chance Upcycling Design                            Einzelunternehmer', 'Email': 'info@2chanceupcyclingdesign.de'}
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# Cell In[25], line 6
#       3 driver = webdriver.Edge()
#       5 # Visit the website
# ----> 6 driver.get(link)
#       8 # Get the page source code after the website has fully loaded
#       9 html = driver.page_source
#
# File ~\anaconda3\envs\hello-tf\lib\site-packages\selenium\webdriver\remote\webdriver.py:354, in WebDriver.get(self, url)
#     352 def get(self, url: str) -> None:
#     353     """Loads a web page in the current browser session."""
# --> 354     self.execute(Command.GET, {"url": url})
#
# File ~\anaconda3\envs\hello-tf\lib\site-packages\selenium\webdriver\remote\webdriver.py:345, in WebDriver.execute(self, driver_command, params)
#     343 response = self.command_executor.execute(driver_command, params)
#     344 if response:
# --> 345     self.error_handler.check_response(response)
#     346     response["value"] = self._unwrap_value(response.get("value", None))
#     347     return response
#
# File ~\anaconda3\envs\hello-tf\lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# TimeoutException: Message: timeout: Timed out receiving message from renderer: 296.056
#   (Session info: MicrosoftEdge=115.0.1901.200)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00007FF6B26F5422+69586]
# 	Microsoft::Applications::Events::EventProperty::~EventProperty [0x00007FF6B2685662+760226]
# 	(No symbol) [0x00007FF6B243B8CC]
# 	(No symbol) [0x00007FF6B242437B]
# 	(No symbol) [0x00007FF6B2424194]
# 	(No symbol) [0x00007FF6B24224DD]
# 	(No symbol) [0x00007FF6B242339E]
# 	(No symbol) [0x00007FF6B2431A4F]
# 	(No symbol) [0x00007FF6B2447E09]
# 	(No symbol) [0x00007FF6B244D40A]
# 	(No symbol) [0x00007FF6B2423CF6]
# 	(No symbol) [0x00007FF6B24238CD]
# 	(No symbol) [0x00007FF6B2447B3B]
# 	(No symbol) [0x00007FF6B24BC566]
# 	(No symbol) [0x00007FF6B24A2B83]
# 	(No symbol) [0x00007FF6B247589E]
# 	(No symbol) [0x00007FF6B2474B6B]
# 	(No symbol) [0x00007FF6B2476024]
# 	Microsoft::Applications::Events::ILogManager::DispatchEventBroadcast [0x00007FF6B28CD229+1294553]
# 	(No symbol) [0x00007FF6B24F49F4]
# 	Microsoft::Applications::Events::EventProperty::~EventProperty [0x00007FF6B25D3DF1+33073]
# 	Microsoft::Applications::Events::EventProperty::~EventProperty [0x00007FF6B25CC409+1865]
# 	Microsoft::Applications::Events::ILogManager::DispatchEventBroadcast [0x00007FF6B28CBE01+1289393]
# 	Microsoft::Applications::Events::ILogConfiguration::operator* [0x00007FF6B268DC68+20184]
# 	Microsoft::Applications::Events::ILogConfiguration::operator* [0x00007FF6B268A2F4+5476]
# 	Microsoft::Applications::Events::ILogConfiguration::operator* [0x00007FF6B268A3EC+5724]
# 	Microsoft::Applications::Events::EventProperty::~EventProperty [0x00007FF6B267ECA1+733153]
# 	BaseThreadInitThunk [0x00007FFDA4C07604+20]
# 	RtlUserThreadStart [0x00007FFDA55A26A1+33]

# %%
len(links1)
# Out:
# 164

# %%
data1 = pd.DataFrame(company_data1)
data1
# Out:
#                                                  Name  \
# 0   Bonjour Sérénité                            Ei...
# 1           Schelchen                            GmbH
# 2   Frija Omina                            Einzelu...
# 3    slowli                            - Fair Fashion
# 4             Deepmello                            UG
# 5   Greenbomb                            Ethifashi...
# 6          Mrs.Hippie                            GmbH
# 7   little kiwi                            Einzelu...
# 8   hukkepack                            Einzelhandel
# 9   karlskopf                            UG (haftu...
# 10         Jill Green                            GmbH
# 11  2Chance Upcycling Design                      ...
#
#                              Email
# 0      bonjour@bonjourserenite.com
# 1                    info@pedag.de
# 2             mail@frija-omina.com
# 3                    hey@slowli.de
# 4                info@deepmello.de
# 5                info@greenbomb.de
# 6           knauschner@geh-bunt.de
# 7              info@little-kiwi.de
# 8               hallo@hukkepack.de
# 9               info@karlskopf.net
# 10              info@jillgreen.com
# 11  info@2chanceupcyclingdesign.de

# %%
links2=links1[13:340]

# %%
company_data2 = []
for link in links2:
    driver = webdriver.Edge()

    # Visit the website
    driver.get(link)

    # Get the page source code after the website has fully loaded
    html = driver.page_source

    # Close the browserbbbbb
    driver.quit()

    # Parse the HTML using BeautifulSoup
    soup = BeautifulSoup(html, "html.parser")

    # Find the name and email within the div with class "adressbox"
    adressbox_div = soup.find("div", class_="adressbox")

    # Find the name within the adressbox div
    name_element = adressbox_div.find("strong")
    name = name_element.text.strip() if name_element else "Name not found"

    # Find the email within the adressbox div
    email_element = adressbox_div.find("a")
    email = email_element.text.strip() if email_element else "Email not found"
    
    data = {}
    data['Name'] = name
    data['Email'] = email
    company_data2.append(data)

    print(data)
# Out:
# {'Name': 'SchuhSign                            GmbH&Co. KG', 'Email': 'info@schuhsign.de'}
# {'Name': 'MBaetz                            Einzelunternehmen', 'Email': 'hello@mbaetz.com'}
# {'Name': 'Ethletic                            GmbH', 'Email': 'info@ethletic.com'}
# {'Name': 'Cmig                            Charlotte & Christoph Sörman, GbR', 'Email': 'Cmig@Cmig.se'}
# {'Name': 'INASKA                            GmbH', 'Email': 'hello@inaska.com'}
# {'Name': 'green.in.pieces                            Einzelunternehmen', 'Email': 'support@greeninpieces.de'}
# {'Name': 'Cocon Commerz PRIVATSACHEN                            GmbH', 'Email': 'info@privatsachen.de'}
# {'Name': 'Julia Starp                            Modedesign', 'Email': 'office@reichert-pr.com'}
# {'Name': 'Cotton made in Africa                            Social Business Initiative / Stiftung', 'Email': 'info@abt-foundation.org'}
# {'Name': 'SHIRTS FOR LIFE                            GmbH', 'Email': 'info@shirtsforlife.de'}
# {'Name': 'BELEAF                            GbR', 'Email': 'info@beleaf.shop'}
# {'Name': 'Bracenet                            GmbH', 'Email': 'hello@bracenet.net'}
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# Cell In[30], line 6
#       3 driver = webdriver.Edge()
#       5 # Visit the website
# ----> 6 driver.get(link)
#       8 # Get the page source code after the website has fully loaded
#       9 html = driver.page_source
#
# File ~\anaconda3\envs\hello-tf\lib\site-packages\selenium\webdriver\remote\webdriver.py:354, in WebDriver.get(self, url)
#     352 def get(self, url: str) -> None:
#     353     """Loads a web page in the current browser session."""
# --> 354     self.execute(Command.GET, {"url": url})
#
# File ~\anaconda3\envs\hello-tf\lib\site-packages\selenium\webdriver\remote\webdriver.py:345, in WebDriver.execute(self, driver_command, params)
#     343 response = self.command_executor.execute(driver_command, params)
#     344 if response:
# --> 345     self.error_handler.check_response(response)
#     346     response["value"] = self._unwrap_value(response.get("value", None))
#     347     return response
#
# File ~\anaconda3\envs\hello-tf\lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# TimeoutException: Message: timeout: Timed out receiving message from renderer: 297.578
#   (Session info: MicrosoftEdge=115.0.1901.200)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00007FF6B26F5422+69586]
# 	Microsoft::Applications::Events::EventProperty::~EventProperty [0x00007FF6B2685662+760226]
# 	(No symbol) [0x00007FF6B243B8CC]
# 	(No symbol) [0x00007FF6B242437B]
# 	(No symbol) [0x00007FF6B2424194]
# 	(No symbol) [0x00007FF6B24224DD]
# 	(No symbol) [0x00007FF6B242339E]
# 	(No symbol) [0x00007FF6B2431A4F]
# 	(No symbol) [0x00007FF6B2447E09]
# 	(No symbol) [0x00007FF6B244D40A]
# 	(No symbol) [0x00007FF6B2423CF6]
# 	(No symbol) [0x00007FF6B24238CD]
# 	(No symbol) [0x00007FF6B2447B3B]
# 	(No symbol) [0x00007FF6B24BC566]
# 	(No symbol) [0x00007FF6B24A2B83]
# 	(No symbol) [0x00007FF6B247589E]
# 	(No symbol) [0x00007FF6B2474B6B]
# 	(No symbol) [0x00007FF6B2476024]
# 	Microsoft::Applications::Events::ILogManager::DispatchEventBroadcast [0x00007FF6B28CD229+1294553]
# 	(No symbol) [0x00007FF6B24F49F4]
# 	Microsoft::Applications::Events::EventProperty::~EventProperty [0x00007FF6B25D3DF1+33073]
# 	Microsoft::Applications::Events::EventProperty::~EventProperty [0x00007FF6B25CC409+1865]
# 	Microsoft::Applications::Events::ILogManager::DispatchEventBroadcast [0x00007FF6B28CBE01+1289393]
# 	Microsoft::Applications::Events::ILogConfiguration::operator* [0x00007FF6B268DC68+20184]
# 	Microsoft::Applications::Events::ILogConfiguration::operator* [0x00007FF6B268A2F4+5476]
# 	Microsoft::Applications::Events::ILogConfiguration::operator* [0x00007FF6B268A3EC+5724]
# 	Microsoft::Applications::Events::EventProperty::~EventProperty [0x00007FF6B267ECA1+733153]
# 	BaseThreadInitThunk [0x00007FFDA4C07604+20]
# 	RtlUserThreadStart [0x00007FFDA55A26A1+33]

# %%
links3=links2[13:340]

# %%
len(links3)
# Out:
# 138

# %%
data2 = pd.DataFrame(company_data2)
data2
# Out:
#                                                  Name  \
# 0    SchuhSign                            GmbH&Co. KG
# 1   MBaetz                            Einzeluntern...
# 2            Ethletic                            GmbH
# 3   Cmig                            Charlotte & Ch...
# 4              INASKA                            GmbH
# 5   green.in.pieces                            Ein...
# 6   Cocon Commerz PRIVATSACHEN                    ...
# 7   Julia Starp                            Modedesign
# 8   Cotton made in Africa                         ...
# 9     SHIRTS FOR LIFE                            GmbH
# 10              BELEAF                            GbR
# 11           Bracenet                            GmbH
#
#                        Email
# 0          info@schuhsign.de
# 1           hello@mbaetz.com
# 2          info@ethletic.com
# 3               Cmig@Cmig.se
# 4           hello@inaska.com
# 5   support@greeninpieces.de
# 6       info@privatsachen.de
# 7     office@reichert-pr.com
# 8    info@abt-foundation.org
# 9      info@shirtsforlife.de
# 10          info@beleaf.shop
# 11        hello@bracenet.net

# %%
company_data3 = []
for link in links3:
    driver = webdriver.Edge()

    # Visit the website
    driver.get(link)

    # Get the page source code after the website has fully loaded
    html = driver.page_source

    # Close the browserbbbbb
    driver.quit()

    # Parse the HTML using BeautifulSoup
    soup = BeautifulSoup(html, "html.parser")

    # Find the name and email within the div with class "adressbox"
    adressbox_div = soup.find("div", class_="adressbox")

    # Find the name within the adressbox div
    name_element = adressbox_div.find("strong")
    name = name_element.text.strip() if name_element else "Name not found"

    # Find the email within the adressbox div
    email_element = adressbox_div.find("a")
    email = email_element.text.strip() if email_element else "Email not found"
    
    data = {}
    data['Name'] = name
    data['Email'] = email
    company_data3.append(data)

    print(data)
# Out:
# {'Name': 'Manitober                            GmbH', 'Email': 'service@manitober.de'}
# {'Name': 'Paulsen Fairtitude                            GbR', 'Email': 'hello@jesango.de'}
# {'Name': 'Etiqueta Blanca - Alpaka Mode aus nachhaltiger Produktion                            Einzelunternehmen', 'Email': 'info@alpaka-mode.com'}
# {'Name': 'Marlowe nature - green fashion                            Einzelhandel', 'Email': 'info@marlowe-nature.de'}
# {'Name': 'MYMARINI                            GmbH', 'Email': 'service@mymarini.com'}
# {'Name': 'NOY Hamburg                            GbR', 'Email': 'yannick@noy-hamburg.com'}
# {'Name': 'recolution                            GmbH & Co. KG', 'Email': 'mail@recolution.de'}
# {'Name': 'Lena Schokolade                            Kleinunternehmer', 'Email': 'info@lena-schokolade.de'}
# {'Name': 'MajKay |                            fair | transparent | nachhaltig', 'Email': 'info@majkay.com'}
# {'Name': 'MÁ Hemp Wear - Felde Vertrieb                            GmbH', 'Email': 'info@mahempwear.com'}
# {'Name': 'boochen                            Einzelunternehmen', 'Email': 'hello@boochen.co'}
# {'Name': 'more presents                            e.K.', 'Email': 'info@nachhaltige-baumwolltaschen.de'}
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# Cell In[34], line 6
#       3 driver = webdriver.Edge()
#       5 # Visit the website
# ----> 6 driver.get(link)
#       8 # Get the page source code after the website has fully loaded
#       9 html = driver.page_source
#
# File ~\anaconda3\envs\hello-tf\lib\site-packages\selenium\webdriver\remote\webdriver.py:354, in WebDriver.get(self, url)
#     352 def get(self, url: str) -> None:
#     353     """Loads a web page in the current browser session."""
# --> 354     self.execute(Command.GET, {"url": url})
#
# File ~\anaconda3\envs\hello-tf\lib\site-packages\selenium\webdriver\remote\webdriver.py:345, in WebDriver.execute(self, driver_command, params)
#     343 response = self.command_executor.execute(driver_command, params)
#     344 if response:
# --> 345     self.error_handler.check_response(response)
#     346     response["value"] = self._unwrap_value(response.get("value", None))
#     347     return response
#
# File ~\anaconda3\envs\hello-tf\lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# TimeoutException: Message: timeout: Timed out receiving message from renderer: 296.446
#   (Session info: MicrosoftEdge=115.0.1901.200)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00007FF6B26F5422+69586]
# 	Microsoft::Applications::Events::EventProperty::~EventProperty [0x00007FF6B2685662+760226]
# 	(No symbol) [0x00007FF6B243B8CC]
# 	(No symbol) [0x00007FF6B242437B]
# 	(No symbol) [0x00007FF6B2424194]
# 	(No symbol) [0x00007FF6B24224DD]
# 	(No symbol) [0x00007FF6B242339E]
# 	(No symbol) [0x00007FF6B2431A4F]
# 	(No symbol) [0x00007FF6B2447E09]
# 	(No symbol) [0x00007FF6B244D40A]
# 	(No symbol) [0x00007FF6B2423CF6]
# 	(No symbol) [0x00007FF6B24238CD]
# 	(No symbol) [0x00007FF6B2447B3B]
# 	(No symbol) [0x00007FF6B24BC566]
# 	(No symbol) [0x00007FF6B24A2B83]
# 	(No symbol) [0x00007FF6B247589E]
# 	(No symbol) [0x00007FF6B2474B6B]
# 	(No symbol) [0x00007FF6B2476024]
# 	Microsoft::Applications::Events::ILogManager::DispatchEventBroadcast [0x00007FF6B28CD229+1294553]
# 	(No symbol) [0x00007FF6B24F49F4]
# 	Microsoft::Applications::Events::EventProperty::~EventProperty [0x00007FF6B25D3DF1+33073]
# 	Microsoft::Applications::Events::EventProperty::~EventProperty [0x00007FF6B25CC409+1865]
# 	Microsoft::Applications::Events::ILogManager::DispatchEventBroadcast [0x00007FF6B28CBE01+1289393]
# 	Microsoft::Applications::Events::ILogConfiguration::operator* [0x00007FF6B268DC68+20184]
# 	Microsoft::Applications::Events::ILogConfiguration::operator* [0x00007FF6B268A2F4+5476]
# 	Microsoft::Applications::Events::ILogConfiguration::operator* [0x00007FF6B268A3EC+5724]
# 	Microsoft::Applications::Events::EventProperty::~EventProperty [0x00007FF6B267ECA1+733153]
# 	BaseThreadInitThunk [0x00007FFDA4C07604+20]
# 	RtlUserThreadStart [0x00007FFDA55A26A1+33]

# %%
data3 = pd.DataFrame(company_data3)
data3
# Out:
#                                                  Name  \
# 0           Manitober                            GmbH
# 1   Paulsen Fairtitude                            GbR
# 2   Etiqueta Blanca - Alpaka Mode aus nachhaltiger...
# 3   Marlowe nature - green fashion                ...
# 4            MYMARINI                            GmbH
# 5          NOY Hamburg                            GbR
# 6   recolution                            GmbH & C...
# 7   Lena Schokolade                            Kle...
# 8   MajKay |                            fair | tra...
# 9   MÁ Hemp Wear - Felde Vertrieb                 ...
# 10  boochen                            Einzelunter...
# 11      more presents                            e.K.
#
#                                   Email
# 0                  service@manitober.de
# 1                      hello@jesango.de
# 2                  info@alpaka-mode.com
# 3                info@marlowe-nature.de
# 4                  service@mymarini.com
# 5               yannick@noy-hamburg.com
# 6                    mail@recolution.de
# 7               info@lena-schokolade.de
# 8                       info@majkay.com
# 9                   info@mahempwear.com
# 10                     hello@boochen.co
# 11  info@nachhaltige-baumwolltaschen.de

# %%
links4=links3[13:340]

# %%
company_data4 = []
for link in links4:
    driver = webdriver.Edge()

    # Visit the website
    driver.get(link)

    # Get the page source code after the website has fully loaded
    html = driver.page_source

    # Close the browserbbbbb
    driver.quit()

    # Parse the HTML using BeautifulSoup
    soup = BeautifulSoup(html, "html.parser")

    # Find the name and email within the div with class "adressbox"
    adressbox_div = soup.find("div", class_="adressbox")

    # Find the name within the adressbox div
    name_element = adressbox_div.find("strong")
    name = name_element.text.strip() if name_element else "Name not found"

    # Find the email within the adressbox div
    email_element = adressbox_div.find("a")
    email = email_element.text.strip() if email_element else "Email not found"
    
    data = {}
    data['Name'] = name
    data['Email'] = email
    company_data4.append(data)

    print(data)
# Out:
# {'Name': 'Derbe                            e.K.', 'Email': 'info@derbe-hamburg.de'}
# {'Name': 'Mondkind von Fesche                            Einzelunternehmen', 'Email': 'mondkindvonfesche@gmail.com'}
# {'Name': '8bft fashion-evolution                            GmbH', 'Email': 'kontakt@8bft.hamburg'}
# {'Name': 'dieLOGOgmbh, Agentur für Kunst und Kommunikation                            GmbH', 'Email': 'wir@dieLOGOgmbh.de'}
# {'Name': 'Filigrana Schmuck - Individual Design Products                            UG', 'Email': 'info@filigrana-schmuck.de'}
# {'Name': 'soki Label & Store                            Einzelunternehmen', 'Email': 'info@soki-store.de'}
# {'Name': 'ALEXASCHA Design Studio                            GmbH', 'Email': 'info@alexascha.de'}
# {'Name': 'like a bird lifestyle                            GmbH', 'Email': 'info@like-a-bird.de'}
# {'Name': 'manbefair.com, Inh. Selma Müller                            Einzelfirma', 'Email': 'info@manbefair.com'}
# {'Name': 'Le Pirol                            GmbH', 'Email': 'Hello@lepirol.com'}
# {'Name': 'mamalila                            GmbH', 'Email': 'info@mamalila.de'}
# {'Name': 'JuliaPilot.de / Reflectstar                            GmbH', 'Email': 'wirhelfen@juliapilot.com'}
# {'Name': 'Sandstrasse                            (Person)', 'Email': 'info@sandstrasse.com'}
# {'Name': 'Gudrun Sjödén                            GmbH', 'Email': 'info@gudrunsjoeden.de'}
# {'Name': 'roots of compassion                            eG', 'Email': 'info@rootsofcompassion.org'}
# {'Name': 'SAY time                            GbR', 'Email': 'info@say-time.com'}
# {'Name': 'KaisuMari                            Einzelkauffrau', 'Email': 'info@kaisumari.de'}
# {'Name': 'WEITBLICK®                            GmbH & Co. KG', 'Email': 'service@weitblick.vision'}
# {'Name': "Harold's Lederwaren                            GmbH", 'Email': 'kontakt@harolds-bags.com'}
# {'Name': 'FairBleiben                            Einzelunternehmen', 'Email': 'nachricht@fairbleiben.com'}
# {'Name': 'WePack                            UG (haftungsbeschränkt)', 'Email': 'hello@wepack.bio'}
# {'Name': 'Hohenloher Wolle                            GmbH', 'Email': 'info@schoppel-wolle.de'}
# {'Name': 'Angels Ambition                            BTQS Schönbuchner GbR', 'Email': 'kontakt@angels-ambition.de'}
# {'Name': 'Jack Wolfskin Ausrüstung für Draußen                            GmbH & Co. KGaA', 'Email': 'info@jack-wolfskin.com'}
# {'Name': 'NATIVE SOULS organic-fair-fashion                            Einzelunternehmung', 'Email': 'info@nativesouls.de'}
# {'Name': 'Sperling                            GbR', 'Email': 'service@sperling-bags.com'}
# {'Name': 'Blaumann-Jeanshosen                             GmbH', 'Email': 'guido@blaumann-jeanshosen.de'}
# {'Name': 'People Wear Organic                            GmbH', 'Email': 'mail@peoplewearorganic.de'}
# {'Name': 'Schuh & Mode Kipp                            Einzelhandelsgesellschaft', 'Email': 'info@kipp-schuhe.de'}
# {'Name': 'Human Family                            GbR', 'Email': 'info@human-family.com'}
# {'Name': 'Africulture                            GbR', 'Email': 'info@africulture.de'}
# {'Name': 'Think! Schuhwerk                            GmbH', 'Email': 'manuela.schediwy@legero-united.com'}
# {'Name': 'Ehrenkind                            formbench GmbH', 'Email': 'info@formbench.com'}
# {'Name': 'Ulalü - Ulla Lüer Modedesign                            Einzelunternehmen', 'Email': 'info@ulalue.de'}
# {'Name': 'diejuju                            Einzelunternehmen', 'Email': 'info@diejuju.de'}
# {'Name': 'Róka - fair clothing                            Einzelunternehmen', 'Email': 'info@roka-fairclothing.de'}
# {'Name': 'skarabea                            Einzelunternehmen', 'Email': 'hello@skarabea.de'}
# {'Name': 'KHAFFEE - Taschen ohne Plastik                            Einzelunternehmen', 'Email': 'info@khaffee.de'}
# {'Name': 'Anna und Paul                            GmbH', 'Email': 'email@annaundpaul.de'}
# {'Name': 'BUDEVI                            GbR', 'Email': 'halina@budevi.com'}
# {'Name': 'emma & noah                            Emma & noah GmbH', 'Email': 'flaschenpost@emmanoah.com'}
# {'Name': 'Dailybread                            GmbH', 'Email': 'info@dailybread.eu'}
# {'Name': 'KAYA&KATO                            GmbH', 'Email': 'info@kaya-kato.de'}
# {'Name': 'Sneakers Unplugged                            Einzelunternehmen', 'Email': 'hello@sneakers-unplugged.de'}
# {'Name': 'MATES OF NATURE                            // Sahler & Moore GbR', 'Email': 'info@matesofnature.com'}
# {'Name': 'Fremdformat                            Einzelunternehmen', 'Email': 'info@fremdformat.de'}
# {'Name': 'fejn jewelry                            Einzelunternehmen', 'Email': 'info@fejn.com'}
# {'Name': 'livingResponsible                            SOCIAL² UG (haftungsbeschränkt)', 'Email': 'service@livingresponsible.de'}
# {'Name': 'FOND OF                            GmbH', 'Email': 'info@fondof.de'}
# {'Name': 'ARMEDANGELS                            GmbH', 'Email': 'shop@armedangels.com'}
# {'Name': 'dressgoat                            GbR', 'Email': 'support@dressgoat.de'}
# {'Name': 'PHYNE                            GmbH', 'Email': 'kontakt@phyne.com'}
# {'Name': 'Vorfreude                            GmbH', 'Email': 'fraguns@erlich-textil.de'}
# {'Name': "DAILY'S NOTHING'S BETTER                            GmbH", 'Email': 'online@dailysnothingsbetter.com'}
# {'Name': 'Feuerwear                            GmbH & Co. KG', 'Email': 'info@feuerwear.de'}
# {'Name': 'Taynie                            Einzelunternehmen', 'Email': 'info@taynie.de'}
# {'Name': 'Greenpicks                            Einzelunternehmen', 'Email': 'kontakt@greenpicks.de'}
# {'Name': 'Sinfinis - FTS Fair Trade Shop                            GmbH', 'Email': 'leonie@sinfinis.de'}
# {'Name': 'Belle Ikat                             UG', 'Email': 'info@belleikat.de'}
# {'Name': 'Blümchen Stoffwindel GmbH                            GmbH', 'Email': 'office@stoffwindelcompany.at'}
# {'Name': 'Deuter Sport                             GmbH', 'Email': 'info@deuter.com'}
# {'Name': 'PAPERO®                            Einzelunternehmer', 'Email': 'info@yesmarketing.de'}
# {'Name': 'GreenFeet                            Einzelunternehmen', 'Email': 'Info@Einlagen-Shop.com'}
# {'Name': 'Dilling Unterwäsche                            A/S', 'Email': 'Kundenservice@dilling-unterwaesche.de'}
# {'Name': 'Moyakora                            Einzelunternehmer', 'Email': 'contact@moyakora.de'}
# {'Name': 'Nordwärts                            | Tietz, Sperling und Herrlein GbR', 'Email': 'info@nordwarts.de'}
# {'Name': 'pajama-day                            e.U.', 'Email': 'info@pajama-day.com'}
# {'Name': 'Cannamoda Textilien aus Hanf                            Einzelfirma', 'Email': 'p.rusch@cannamoda.de'}
# {'Name': 'denkefair                            Einzelunternehmen', 'Email': 'info@denkefair.de'}
# {'Name': 'gotsutsumu                            GmbH', 'Email': 'info@gotsutsumu.de'}
# {'Name': 'karokönig ecotailoring                            Einzelunternehmen', 'Email': 'hello@karokoenig,com'}
# {'Name': 'KorkAllee.de                            GmbH', 'Email': 'service@korkallee.de'}
# {'Name': 'Bamigo                            GmbH', 'Email': 'info@bamigo.de'}
# {'Name': 'be free® stuff                            UG', 'Email': 'info@befree.shoes'}
# {'Name': 'OGNX                            GmbH', 'Email': 'contact@ognx.com'}
# {'Name': 'CÉLINE VOGEL                            Einzelunternehmen', 'Email': 'celine_vogel[at]gmx.de'}
# {'Name': 'SANVT                            GmbH', 'Email': 'care@sanvt.com'}
# {'Name': 'Liapure Design Studio                            Einzelunternehmen', 'Email': 'contact@liapure.de'}
# {'Name': 'ThokkThokk                            GmbH & Co. KG', 'Email': 'support@thokkthokk.com'}
# {'Name': 'PLANETICS                            UG', 'Email': 'support@planetics.de'}
# {'Name': 'Kipepeo-Clothing                            Einzelunternehmen', 'Email': 'info@kipepeo-clothing.com'}
# {'Name': 'YOU LOOK PERFECT                            Inh. Sandra Milacher', 'Email': 'info@youlookperfect.at'}
# {'Name': 'Lori                            Einzelunternehmer', 'Email': 'info@lori-welt.de'}
# {'Name': 'Schöffel Sportbekleidung                             GmbH', 'Email': 'presse@schoeffel.de'}
# {'Name': 'mantrafant                            GmbH', 'Email': 'team@mantrafant.com'}
# {'Name': 'Schnuffelinis                            Einzelunternehmen', 'Email': 'service@schnuffelinis.de'}
# {'Name': 'ORAIN                            GmbH', 'Email': 'office@raincombi.at'}
# {'Name': 'Martin Guthmann Schmuckmanufaktur seit 1906                            e.K.', 'Email': 'martin@guthmann.com'}
# {'Name': 'Jürgen Brand - Fair Fashion Manufactured in Austria                            Einzelunternehmen', 'Email': 'juergen@juergenbrand.com'}
# {'Name': 'Nura Kassoume                            Einzelhandel', 'Email': 'office@aurinshop.at'}
# {'Name': 'Schauraum für angewandte Kunst                            Einzelunternehmen', 'Email': 'office@schauraum.at'}
# {'Name': 'Mama Ocllo Import                            UG (haftungsbeschränkt)', 'Email': 'martina@chillnfeel.com'}
# {'Name': 'Daniela Paradeis                            EPU', 'Email': 'info@danielaparadeis.com'}
# {'Name': 'GREEN SHIRTS                            EG', 'Email': 'service@green-shirts.com'}
# {'Name': 'COTONEA                            Gebr. Elmer & Zweifel GmbH & Co. KG', 'Email': 'info@cotonea.de'}
# {'Name': 'Waldorfshop - Universnatur                             GmbH', 'Email': 'kundenservice@waldorfshop.eu'}
# {'Name': 'burggrafburggraf                            // Burggraf Burggraf-Reusch GbR', 'Email': 'info@burggrafburggraf.de'}
# {'Name': 'KOKOworld                            Einzelunternehmen', 'Email': 'hello@kokoworld.de'}
# {'Name': 'Soulcover                            Kleinunternehmer', 'Email': 'kontakt@soulcover-clothing.de'}
# {'Name': 'respecca handel.t                            Einzelunternehmen', 'Email': 'shop@respecca.com'}
# {'Name': 'VAPUS.organics by Punya                            GmbH', 'Email': 'info@vapus.org'}
# {'Name': 'LDP Homemade                            e.U.', 'Email': 'hello@ldp-homemade.de'}
# {'Name': 'Speidel                            GmbH', 'Email': 'info@speidelshop.com'}
# {'Name': 'Infinite Running                            GmbH', 'Email': 'info@infinite-running.de'}
# {'Name': 'LOVJOI Organic Clothing                            GmbH', 'Email': 'info@lovjoi.com'}
# {'Name': 'Wollerei                            Einzelunternehmen', 'Email': 'shop@wollerei.at'}
# {'Name': 'ResTasch                            Handgenähte Jeanstaschen aus Österreich', 'Email': 'restasch@chello.at'}
# {'Name': 'Ompura                            GmbH', 'Email': 'service@ompura.com'}
# {'Name': 'Comazo                            GmbH & Co.KG', 'Email': 'info@comazo.de'}
# {'Name': 'Project Cece                            NL: Vennootschap onder firma', 'Email': 'info@projectcece.nl'}
# {'Name': 'Schäfereigenossenschaft Finkhof                            eG', 'Email': 'info@finkhof.de'}
# {'Name': 'King Louie                            - Vintage inspirietre Mode aus Amsterdam', 'Email': 'onlineshop@kinglouie.de'}
# {'Name': 'Robin                             | hochgrat textil GmbH', 'Email': 'hello@robin-shop.com'}
# {'Name': 'VAUDE Sport                            GmbH & Co.KG', 'Email': 'sustainability@vaude.com'}
# {'Name': 'M-KA                            Kleinunternehmer', 'Email': 'info@mka-kreativ.de'}
# {'Name': 'BRUNA the Label                            GmbH', 'Email': 'hello@brunathelabel.com'}
# {'Name': 'AURHEN ecofair                            Einzelunternehmen', 'Email': 'info@aurhen.de'}
# {'Name': 'AlpacaOne                            GmbH', 'Email': 'info@alpacaone.de'}
# {'Name': '3FREUNDE                            Einzelfirma', 'Email': 'info@3freunde.com'}
# {'Name': 'Iron Roots                            VOF', 'Email': 'info@ironroots.nl'}
# {'Name': 'Coa Coa / Ursula Piber & Ines Häfner                             GbR', 'Email': 'ines@coagoa.com'}
# {'Name': 'zündstoff - fair organic clothing                            GbR', 'Email': 'info@zuendstoff-clothing.de'}
# {'Name': 'Laimer                            GmbH', 'Email': 'info@laimer.bz'}
# {'Name': 'Edeltruhe                            - kreativ und individuell', 'Email': 'edeltruhe@edeltruhe.de'}
# {'Name': 'Korkeria | Aus Kork. Für Dich.', 'Email': 'shop@korkeria.ch'}

# %%
data4 = pd.DataFrame(company_data4)
data4
# Out:
#                                                   Name  \
# 0                Derbe                            e.K.
# 1    Mondkind von Fesche                           ...
# 2    8bft fashion-evolution                        ...
# 3    dieLOGOgmbh, Agentur für Kunst und Kommunikati...
# 4    Filigrana Schmuck - Individual Design Products...
# ..                                                 ...
# 120  Coa Coa / Ursula Piber & Ines Häfner          ...
# 121  zündstoff - fair organic clothing             ...
# 122             Laimer                            GmbH
# 123  Edeltruhe                            - kreativ...
# 124                     Korkeria | Aus Kork. Für Dich.
#
#                            Email
# 0          info@derbe-hamburg.de
# 1    mondkindvonfesche@gmail.com
# 2           kontakt@8bft.hamburg
# 3             wir@dieLOGOgmbh.de
# 4      info@filigrana-schmuck.de
# ..                           ...
# 120              ines@coagoa.com
# 121  info@zuendstoff-clothing.de
# 122               info@laimer.bz
# 123       edeltruhe@edeltruhe.de
# 124             shop@korkeria.ch
#
# [125 rows x 2 columns]

# %%
Company=pd.concat([data,data1,data2,data3,data4],axis=0)

# %%
Company = Company.reset_index(drop=True)

# %%
Company.to_csv('Company2.csv')
