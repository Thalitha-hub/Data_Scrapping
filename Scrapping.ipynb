# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import time

# Path to the Microsoft Edge WebDriver executable
# driver_path = "/path/to/msedgedriver"
# Create a new instance of Microsoft Edge
driver = webdriver.Edge()

# Visit the dynamic website
driver.get("https://www.lifeverde.de/gruene-unternehmen/nachhaltige-ernaehrung-u-gesundheit")

# Scroll down to load more content
# Adjust the number of iterations based on the page's structure
for _ in range(25):
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(5)  # Wait for the content to load, you can adjust the delay if needed

# Get the page source code after the website has fully loaded
html = driver.page_source

# Close the browser
driver.quit()

# Parse the HTML using BeautifulSoup
soup = BeautifulSoup(html, "html.parser")

# Find all the links with class "firmenname"
links = []  # List to store the extracted links
for link in soup.find_all('a', class_='firmenname'):  # Specify the desired class attribute
    href = link.get('href')
    links.append(href)
# # Print the links
# for link in links:
#     print(link["href"])

# %%
# !pip install selenium

# %%
len(links)
# Out:
# 360

# %%
links[0]
# Out:
# 'https://www.lifeverde.de/gruene-unternehmen/nachhaltige-ernaehrung-u-gesundheit/cbdweltde-der-endower'

# %%
company_data = []
for link in links:
    driver = webdriver.Edge()

    # Visit the website
    driver.get(link)

    # Get the page source code after the website has fully loaded
    html = driver.page_source

    # Close the browser
    driver.quit()

    # Parse the HTML using BeautifulSoup
    soup = BeautifulSoup(html, "html.parser")

    # Find the name and email within the div with class "adressbox"
    adressbox_div = soup.find("div", class_="adressbox")

    # Find the name within the adressbox div
    name_element = adressbox_div.find("strong")
    name = name_element.text.strip() if name_element else "Name not found"

    # Find the email within the adressbox div
    email_element = adressbox_div.find("a")
    email = email_element.text.strip() if email_element else "Email not found"
    
    data = {}
    data['Name'] = name
    data['Email'] = email
    company_data.append(data)

    print(data)
# Out:
# {'Name': 'CBDwelt.de der Endower                            GmbH', 'Email': 'info@cbdwelt.de'}
# {'Name': 'EASYFITNESS Franchise                             GmbH', 'Email': 'info@easyfitness.club'}
# {'Name': 'ganio.de                            Einzelunternehmen', 'Email': 'info@ganio.de'}
# {'Name': 'Eine Marke der Centerboard Holdings                             Incorporation', 'Email': 'service@herbano.com'}
# {'Name': 'This Is Vegan - Plantbased Lifestyle Magazin                            Einzelunternehmen', 'Email': 'info@this-is-vegan.com'}
# {'Name': 'SONNENTOR Kräuterhandelsgesellschaft                            mbH', 'Email': 'online@sonnentor.com'}
# {'Name': 'Vegan Box                            GmbH', 'Email': 'info@vegan-box.de'}
# {'Name': 'Compster                            GbR', 'Email': 'info@wurmturm.com'}
# {'Name': 'Styleholz                            GmbH', 'Email': 'hallo@styleholz.com'}
# {'Name': 'Kazi Yetu                            UG', 'Email': 'hello@kazi-yetu.com'}
# {'Name': 'Lunettes Selection                            Einzelunternehmen', 'Email': 'info@lunettes-selection.de'}
# {'Name': 'Blanks                             GmbH & Co. KG', 'Email': 'team@vom-achterhof.de'}
# {'Name': 'Rund um die Biene                            e.U.', 'Email': 'info@rund-um-die-biene.at'}
# {'Name': 'Vegablum                            KG', 'Email': 'info@vegablum.de'}
# {'Name': 'JOY NATURALS GmbH                            GmbH', 'Email': 'a.herlbauer@joy-naturals.at'}
# {'Name': 'TeeGschwendner                            GmbH', 'Email': 'teemail@teegschwendner.de'}
# {'Name': 'Balteschwiler Consulting                            Einzelfirma', 'Email': 'info@balteschwilerconsulting.ch'}
# {'Name': 'Honest & Rare                            UG', 'Email': 'cheers@honest-rare.de'}
# {'Name': 'NakedNature Naturkosmetik                            Einzelunternehmen', 'Email': 'kontakt@nakednature.de'}
# {'Name': 'Futonwerk & Neonatura                            GmbH', 'Email': 'ug@futonwerk.de'}
# {'Name': 'BKK ProVita – Die Kasse fürs Leben.                            -', 'Email': 'info@bkk-provita.de'}
# {'Name': 'Peel Of Tea                            UG', 'Email': 'office@peel-of-tea.de'}
# {'Name': 'Govinda Natur                             GmbH', 'Email': 'info@govindanatur.de'}
# {'Name': 'Fachingen Heil- und Mineralbrunnen                            GmbH', 'Email': 'info@fachingen.de'}
# {'Name': 'Blaufaktor GmbH & Co. KG                            GmbH & Co. KG', 'Email': 'info@blaufaktor.de'}
# {'Name': 'Linario                            GmbH', 'Email': 'mail@linario.de'}
# {'Name': 'Zimply Natural                             GmbH', 'Email': 'kontakt@zimplynatural.de'}
# {'Name': 'Fontaine Nahrungsmittel                            GmbH', 'Email': 'info@fontainefood.de'}
# {'Name': 'Lichtgrün                            GmbH', 'Email': 'info@lichtgruen-cosmetics.com'}
# {'Name': 'Kaufdahoam.at                            OG', 'Email': 'Office@kaufdahoam.at'}
# {'Name': 'bluvion                            GmbH', 'Email': 'wecare@blubonbon.com'}
# {'Name': 'OraGarden                            GmbH', 'Email': 'marketing@oragarden.de'}
# {'Name': 'CONSULTA AG                            Aktiengesellschaft', 'Email': 'info@consulta-ag.de'}
# {'Name': 'Glocal Food & Drinks Rüdiger Olschewski                            GbR', 'Email': 'info@glocalgin.de'}
# {'Name': 'Forever Thirsty                            GmbH', 'Email': 'contact@forever-thirsty.com'}
# {'Name': 'Kluuf                            GmbH', 'Email': 'info@kluuf.com'}
# {'Name': 'LANGE & REBSCH GROUP                            GmbH', 'Email': 'hallo@liebelei.me'}
# {'Name': 'Grote & Co. Spirits oHG                            oHG', 'Email': 'grote@grote-spirits.com'}
# {'Name': 'greenyogashop                            GmbH', 'Email': 'info@greenyogashop.com'}
# {'Name': 'Delinat                            AG', 'Email': 'kundenservice@delinat.com'}
# {'Name': 'Value for Generations                            GmbH', 'Email': 'greenkitchen.val4gen@gmail.com'}
# {'Name': 'Bioland Weingut Ansgar Galler                            Einzelunternehmen', 'Email': 'mail@weingut-galler.de'}
# {'Name': 'bamtoo                            Einzelunternehmen', 'Email': 'info@bamtoo.de'}
# {'Name': 'lkm                            kmlk', 'Email': 'noack@jobverde.de'}
# {'Name': 'Feel                             Limited Company', 'Email': 'hallo@wearefeel.com'}
# {'Name': 'caámate                            Einzelunternehmen', 'Email': 'info@caamate.de'}
# {'Name': 'EVR Medical Conceptions                             GmbH', 'Email': 'info@dermaplan.de'}
# {'Name': 'Ethno-Health                            Group BV', 'Email': 'info@ethno-health.com'}
# {'Name': 'my-Biowine - Günter M. Rindt                            Einzelunternehmen', 'Email': 'office@my-biowine.de'}
# {'Name': 'Nutrition-Plus Germany                             e.K.', 'Email': 'info@nutri-plus.de'}
# {'Name': 'goodmoodfood                            GmbH', 'Email': 'office@goodmood-food.net'}
# {'Name': 'Dr. Enzo Backmischungen für Hunde                            Einzelunternehmen', 'Email': 'info@drenzo.de'}
# {'Name': 'Holle baby food                            AG', 'Email': 'babyfood@holle.ch'}
# {'Name': 'Peturo                             GmbH', 'Email': 'alex@mammaly.de'}
# {'Name': 'Marsapet                            GmbH', 'Email': 'kontakt@marsapet.de'}
# {'Name': 'Green Petfood                            (foodforplanet GmbH & Co. KG)', 'Email': 'green-petfood@foodforplanet.de'}
# {'Name': 'Yarrah Organic Petfood                             BV', 'Email': 'info@yarrah.com'}
# {'Name': 'Rose Office                            GmbH', 'Email': 'info@rose-office.com'}
# {'Name': 'Aries Athletics                            GbR', 'Email': 'info@ariesathletics.de'}
# {'Name': 'KoRo                            Handels GmbH', 'Email': 'service@korodrogerie.de'}
# {'Name': 'MEIN GENUSS                            GmbH', 'Email': 'service@meingenuss.de'}
# {'Name': 'Original Beans                            B.V.', 'Email': 'info@originalbeans.com'}
# {'Name': 'Alpine White', 'Email': 'info@alpinewhite.ch'}
# {'Name': 'Miezenhaps                            Einzelunternehmen', 'Email': 'jessica.jungmann@miezenhaps.de'}
# {'Name': 'esskultour Catering Köln                            UG', 'Email': 'post@esskultour-koeln.de'}
# {'Name': 'Fairnatural                            GmbH', 'Email': 'info@fairnatural.de'}
# {'Name': 'MyCupOfTea                             GmbH', 'Email': 'info@mycupoftea-shop.com'}
# {'Name': 'Breathe Solutions                            GmbH', 'Email': 'hello@breathe-organics.com'}
# {'Name': 'meinetage.at - nachhaltige Monatshygiene                            Einzelunternehmen', 'Email': 'kontakt@meinetage.at'}
# {'Name': 'Nature Basics                            GmbH', 'Email': 'friends@naturebasics.de'}
# {'Name': 'Yummy Organics                            GmbH', 'Email': 'info@yummy-organics.de'}
# {'Name': 'ELMT                            UG', 'Email': 'hello@inner-elmt.com'}
# {'Name': 'Umwelt-Bildungszentrum Berlin                            gGmbH', 'Email': 'info@umwelt-bildungszentrum.de'}
# {'Name': 'Black Bear                            GmbH', 'Email': 'office@black-bear.at'}
# {'Name': 'Quorn Smart Life                            GmbH', 'Email': 'QuornSL@quornfoods.com'}
# {'Name': 'Backefix - by Sprouting                            GmbH', 'Email': 'info@backefix.com'}
# {'Name': 'Kurhaus Marienkron                             GmbH', 'Email': 'info@marienkron.at'}
# {'Name': 'Libuni                             Verein', 'Email': 'verein@libuni.eu'}
# {'Name': 'El Puente                            GmbH', 'Email': 'info@el-puente.de'}
# {'Name': 'Biomarkt Lämmerhof                            Inhabergeführt', 'Email': 'hofladen@laemmerhof.de'}
# {'Name': 'Haus Neumühle, Restaurant-Hotel natürlich bio                            Einzelfirma', 'Email': 'info@neumuehle.ch'}
# {'Name': 'Hanfland                            GmbH', 'Email': 'office@hanfand.at'}
# {'Name': 'Förderkreis Biozyklisch-Veganer Anbau e.V.                             e.V.', 'Email': 'foerderkreis@biozyklisch-vegan.org'}
# {'Name': 'Veda Naturals                            GmbH', 'Email': 'info@vedanaturals.de'}
# {'Name': 'Brüder Unterweger                            GesmbH', 'Email': 'office@unterweger-wellness.com'}
# {'Name': 'founderholics                            GmbH', 'Email': 'friends@founderholics.com'}
# {'Name': 'AlpenPower                            GmbH', 'Email': 'service@alpenpower.com'}
# {'Name': 'Swaytis                            GmbH', 'Email': 'info@swaytis.de'}
# {'Name': 'Kloster Kitchen – eine Marke der curameo AG                            AG', 'Email': 'marketing@klosterkitchen.com'}
# {'Name': 'SIRPLUS GmbH                            GmbH', 'Email': 'mail@sirplus.de'}
# {'Name': 'WeltPartner eG                            eingetragene Genossenschaft', 'Email': 'info@weltpartner.de'}
# {'Name': 'The Plant Magic Company                            GmbH', 'Email': 'hi@theplantmagic.co'}
# {'Name': 'Kulmine                            e. K.', 'Email': 'post@kulmine.de'}
# {'Name': 'lacely GmbH                            GmbH', 'Email': 'info@lacely-group.com'}
# {'Name': 'GOOPACKO                            GmbH', 'Email': 'hallo@goopacko.de'}
# {'Name': 'Institut Dr. Rilling Healthcare                             GmbH', 'Email': 'info@rilling-healthcare.de'}
# {'Name': 'faktura                             gGmbH', 'Email': 'mail@faktura-berlin.de'}
# {'Name': 'Packtive Entertainment                            UG', 'Email': 'servus@packtive.de'}
# {'Name': 'be tanics GmbH                            GmbH', 'Email': 'hello@betanics.de'}
# {'Name': 'CBDSI                            GmbH', 'Email': 'lifeverde@cbdcielo.org'}
# {'Name': 'Scandinavian Biolabs                            ApS', 'Email': 'kontakt@scandinavianbiolabs.de'}
# {'Name': 'health1                            GmbH', 'Email': 'hello@miapanda.de'}
# {'Name': 'VITA INVEST                            Einzelfirma', 'Email': 'info@vita-invest.eu'}
# {'Name': 'vetevo                            GmbH', 'Email': 'info@vetevo.de'}
# {'Name': 'dualseele                            Einzelunternehmen', 'Email': 'info@dualseele-yoga.de'}
# {'Name': 'purento                            GmbH', 'Email': 'info@terra-pura-tiernahrung.de'}
# {'Name': 'Vivobase                            GmbH', 'Email': 'info@vivobase.de'}
# {'Name': 'Zai Organic Products & Communications                            GmbH', 'Email': 'argiris.valdramidis@zai-tea.com'}
# {'Name': 'Deine Ernährung                            Einzelunternehmen', 'Email': 'info@deine-ernaehrung.de'}
# {'Name': 'ecodemy                            GmbH', 'Email': 'info@ecodemy.de'}
# {'Name': 'Droste-Laux Naturkosmetik                            GmbH & Co. KG', 'Email': 'info@droste-laux.de'}
# {'Name': 'WINEGINEERS                            Einzelunternehmen', 'Email': 'info@winegineers.de'}
# {'Name': 'Sommerhanf -                             DCM - Deutsche Cannabis Manufaktur UG (haftungsbeschränkt)', 'Email': 'marketing@sommerhanf.de'}
# {'Name': 'foodloose                            GmbH', 'Email': 'kooperationen@foodloose.net'}
# {'Name': 'OneLife                            GmbH', 'Email': 'mail@onelife.eco'}
# {'Name': 'Ofner DER BACKPROFI                            GmbH', 'Email': 'office@derbackprofi.at'}
# {'Name': 'tempehmanufaktur - Schnappinger                            GmbH', 'Email': 'info@tempehmanufaktur.net'}
# {'Name': 'the nu company                            GmbH', 'Email': 'info@the-nu-company.com'}
# {'Name': 'biowein-erlesen Weinhandel Olaf Nitzsche                            Einzelunternehmen', 'Email': 'info@biowein-erlesen.de'}
# {'Name': 'Hoffmann Germany                            GmbH', 'Email': 'info@hoffmann-germany.de'}
# {'Name': 'Grafschafter Krautfabrik                            GmbH & Co. KG', 'Email': 'krautfabrik@grafschafter.de'}
# {'Name': 'Kräuterkontor - Verbena VH Handels                            GmbH', 'Email': 'info@kraeuterkontor.de'}
# {'Name': 'Sole Runner                            Einzelunternehmen', 'Email': 'info@sole-runner.com'}
# {'Name': 'ManuTeeFaktur                            GmbH', 'Email': 'info@manuteefaktur.com'}
# {'Name': 'Voi Guad                            GbR', 'Email': 'info@voi-guad.de'}
# {'Name': 'for you eHealth                            GmbH', 'Email': 'info@foryouehealth.de'}
# {'Name': 'Now2You Handels GmbH                            GmbH', 'Email': 'service@now2you.at'}
# {'Name': 'Kaffeerösterei PeRu                            Einzelunternehmen', 'Email': 'info@cafe-peru.de'}
# {'Name': 'eco2eat                            GmbH', 'Email': 'hello@eco2eat.com'}
# {'Name': 'Meeresgarten                            c/o oceanBASIS GmbH', 'Email': 'info@oceanbasis.de'}
# {'Name': 'Elbe Life Science                            GmbH', 'Email': 'info@elbelifescience.com'}
# {'Name': "Lini's Bites                            UG", 'Email': 'info@linisbites.com'}
# {'Name': 'okäse                            GmbH', 'Email': 'service@okaese.de'}
# {'Name': 'Wacker                            GmbH', 'Email': 'shop@bleibwacker.com'}
# {'Name': 'sunny-tableware GmbH                            GmbH', 'Email': 'info@sunny-tableware.de'}
# {'Name': 'Green-Bag Getränke                            GmbH', 'Email': 'office@green-bag.at'}
# {'Name': 'Carl Wilhelm Clasen                             GmbH', 'Email': 'service@clasen-bio.de'}
# {'Name': 'promavis - BIObay.de                            GmbH', 'Email': 'info@biobay.de'}
# {'Name': 'Geile Vitamine food&supplements                             GmbH', 'Email': 'service@geilevitamine.de'}
# {'Name': 'TISSO Naturprodukte                            GmbH', 'Email': 'info@tisso.de'}
# {'Name': 'smile brush+                            GbR', 'Email': 'info@smilebrushplus.com'}
# {'Name': 'FROG.passion                            GmbH', 'Email': 'service@frogcoffee.de'}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[52], line 21
#      18 adressbox_div = soup.find("div", class_="adressbox")
#      20 # Find the name within the adressbox div
# ---> 21 name_element = adressbox_div.find("strong")
#      22 name = name_element.text.strip() if name_element else "Name not found"
#      24 # Find the email within the adressbox div
#
# AttributeError: 'NoneType' object has no attribute 'find'

# %%
len(company_data)
# Out:
# 142

# %%
import pandas as pd
data = pd.DataFrame(company_data)

# %%
data
# Out:
#                                                   Name  \
# 0    CBDwelt.de der Endower                        ...
# 1    EASYFITNESS Franchise                         ...
# 2    ganio.de                            Einzelunte...
# 3    Eine Marke der Centerboard Holdings           ...
# 4    This Is Vegan - Plantbased Lifestyle Magazin  ...
# ..                                                 ...
# 137  promavis - BIObay.de                          ...
# 138  Geile Vitamine food&supplements               ...
# 139  TISSO Naturprodukte                           ...
# 140        smile brush+                            GbR
# 141       FROG.passion                            GmbH
#
#                         Email
# 0             info@cbdwelt.de
# 1       info@easyfitness.club
# 2               info@ganio.de
# 3         service@herbano.com
# 4      info@this-is-vegan.com
# ..                        ...
# 137            info@biobay.de
# 138  service@geilevitamine.de
# 139             info@tisso.de
# 140   info@smilebrushplus.com
# 141     service@frogcoffee.de
#
# [142 rows x 2 columns]

# %%
links1=links[143:360]

# %%
len(links1)
# Out:
# 217

# %%
company_data1 = []
for link in links1:
    driver = webdriver.Edge()

    # Visit the website
    driver.get(link)

    # Get the page source code after the website has fully loaded
    html = driver.page_source

    # Close the browser
    driver.quit()

    # Parse the HTML using BeautifulSoup
    soup = BeautifulSoup(html, "html.parser")

    # Find the name and email within the div with class "adressbox"
    adressbox_div = soup.find("div", class_="adressbox")

    # Find the name within the adressbox div
    name_element = adressbox_div.find("strong")
    name = name_element.text.strip() if name_element else "Name not found"

    # Find the email within the adressbox div
    email_element = adressbox_div.find("a")
    email = email_element.text.strip() if email_element else "Email not found"
    
    data = {}
    data['Name'] = name
    data['Email'] = email
    company_data1.append(data)

    print(data)
# Out:
# {'Name': 'riva Systemtechnik                             GmbH', 'Email': 'info@riva-filter.de'}
# {'Name': 'STRAYZ Petfood                            GmbH', 'Email': 'info@strayz.de'}
# {'Name': 'niceshops                             GmbH', 'Email': 'office@ecco-verde.com'}
# {'Name': 'CONTIGO Fairtrade                            GmbH', 'Email': 'info@contigo.de'}
# {'Name': 'BWT Sports & Digital Services                            GmbH', 'Email': 'news@bwt.com'}
# {'Name': 'Retulp Custom                            B.V.', 'Email': 'kontakt@retulp.de'}
# {'Name': 'HAKA Kunz                            GmbH', 'Email': 'kontakt@haka.de'}
# {'Name': 'Ayurveda Soulfood                            Eva Baumgartl', 'Email': 'hello@ayurveda-soulfood.de'}
# {'Name': 'CANWAY Schweiz                            GmbH', 'Email': 'kontakt@greenpassion.ch'}
# {'Name': 'Der Zooexperte                            (Marsapet GmbH)', 'Email': 'kontakt@marsapet.de'}
# {'Name': 'Wunschkapsel                            GmbH', 'Email': 'info@wunschkapsel.de'}
# {'Name': 'Primal Harvest                            GmbH', 'Email': 'info@primalharvest.de'}
# {'Name': 'KANNE BROTTRUNK                            GMBH & CO. BETRIEBSGESELLSCHAFT KG', 'Email': 'info@kanne-brottrunk.de'}
# {'Name': 'djoon                            GmbH', 'Email': 'leon@djoon.de'}
# {'Name': 'LiveFresh                            GmbH', 'Email': 'hallo@livefresh.de'}
# {'Name': 'pjyrity©                            GmbH', 'Email': 'dk@pjyrity.com'}
# {'Name': 'PURESUPPLEMENTS by Coach Serdi®                            Enizelunternehmen', 'Email': 'kontakt@purehealthy.eu'}
# {'Name': 'Sprossenliebe                            OG', 'Email': 'post@sprossenliebe-microgreens.com'}
# {'Name': 'Ogaenics                            Novel Nutriology GmbH', 'Email': 'hello@ogaenics.com'}
# {'Name': 'TanteLy - eine Marke der Walter Lang GmbH                            GmbH', 'Email': 'hello@tantely.bio'}
# {'Name': 'Beflora CBD                            Einzelunternehmen', 'Email': 'Ben@beflora.de'}
# {'Name': 'crooked elements                            GmbH', 'Email': 'info@crooked-elements.com'}
# {'Name': 'Nefertem Naturprodukte                            Einzelunternehmung', 'Email': 'info@nefertem-naturprodukte.de'}
# {'Name': 'stick & lembke                            GmbH', 'Email': 'info@stick-lembke.de'}
# {'Name': 'KONTOR 1710                            ac.concept GmbH & Co. KG', 'Email': 'info@kontor1710.de'}
# {'Name': 'KLIMA ARENA                             Der Klima-Erlebnisort', 'Email': 'besucherinfo@klima-arena.de'}
# {'Name': 'PEKANA Naturheilmittel                            GmbH', 'Email': 'info@pekana.com'}
# {'Name': 'LUUP                            GmbH', 'Email': 'info@luupcoffee.de'}
# {'Name': 'HempCrew - Weedo Lifestyle & Media                            GmbH', 'Email': 'support@hempcrew.de'}
# {'Name': 'Münsteraner Finne                            GmbH', 'Email': 'info@finne-brauerei.de'}
# {'Name': 'MyEy Ei-Ersatz                            Öko Insel - GS Handels GmbH', 'Email': 'info@myey.info'}
# {'Name': 'Akal Food - Die Vollwert Spirulina                            Inh. Dr. Frank Winter', 'Email': 'frank@akalfood.de'}
# {'Name': 'Coffee Circle                            Circle Products GmbH', 'Email': 'kontakt@coffeecircle.com'}
# {'Name': 'biond                            GmbH', 'Email': 'info@biond.de'}
# {'Name': 'Leckeres Leinöl                            GbR', 'Email': 'info@leckeres-leinoel.de'}
# {'Name': 'Löwenzahn Organics                            GmbH', 'Email': 'hello@loewenzahnorganics.com'}
# {'Name': 'Blue Farm                            Iconic Drinks GmbH', 'Email': 'presse@bluefarm.co'}
# {'Name': 'SpiceNerds                            GmbH', 'Email': 'info@spicenerds.com'}
# {'Name': 'bJuice                            Smart Drinks GmbH & Co. KG', 'Email': 'info@bjuice.de'}
# {'Name': 'KULAU                            GmbH', 'Email': 'jennifer.riehl@kulau.de'}
# {'Name': 'Better Foodprint                            UG', 'Email': 'kontakt@better-foodprint.de'}
# {'Name': 'My Herbal Diary                             GmbH', 'Email': 'hallo@myherbaldiary.de'}
# {'Name': 'Butterstulle Catering und Service                            GmbH', 'Email': 'post@butterstulle.berlin'}
# {'Name': 'BERLIN SMILE ZAHNZENTRUM                            MVZ', 'Email': 'info@berlin-smile.de'}
# {'Name': 'Eversnack                            Einzelunternehmen', 'Email': 'info@eversnack.de'}
# {'Name': 'Flamingo Road                            UG (haftungsbeschränkt)', 'Email': 'service@traumtropfen.me'}
# {'Name': 'Heimgart /                              EASTSIDE IMPEX Handelsgesellschaft mbH', 'Email': 'post@heimgart.com'}
# {'Name': 'VeggieSweets                            Einzelunternehmen', 'Email': 'info@veggiesweets.de'}
# {'Name': 'Elissón Olive Oil & More                            Inh. Nikos Pulos', 'Email': 'info@elisson.de'}
# {'Name': 'chocri                            GmbH', 'Email': 'info@chocri.de'}
# {'Name': 'Fairment -                             Primal Life GmbH', 'Email': 'briefkasten@fairment.de'}
# {'Name': 'Ökofrost                            GmbH', 'Email': 'info@oekofrost.de'}
# {'Name': 'LUCKY VEGAN - Die vegane Überraschungsbox                            E.', 'Email': 'info@lucky-vegan.com'}
# {'Name': 'SweMa                            GmbH', 'Email': 'info@swema-lebensmittel.de'}
# {'Name': 'Deutsche-Delikatessen.de                            Einzelunternehmen', 'Email': 'kontakt@deutsche-delikatessen.de'}
# {'Name': 'SPICEBAR                            GmbH', 'Email': 'info@spicebar.de'}
# {'Name': "Melro's Best                            GmbH", 'Email': 'info@simplyraw.de'}
# {'Name': 'LIMBUA                            Deutschland GmbH', 'Email': 'info@limbua-group.com'}
# {'Name': "Fru'Cha! GmbH                             Bio und Fairtrade Trockenfrüchte", 'Email': 'office@frucha.de'}
# {'Name': 'Margreblue                             GmbH', 'Email': 'mail@margreblue.de'}
# {'Name': 'Teekampagne                            GmbH', 'Email': 'biotee@projektwerkstatt.com'}
# {'Name': 'Ella´s Basenbande                             GmbH & Co. KG', 'Email': 'jil@basenbande.de'}
# {'Name': 'MAUNAWAI                             GmbH', 'Email': 'info@maunawai.com'}
# {'Name': 'Loma.eco                            GmbH', 'Email': 'support@loma.eco'}
# {'Name': 'SanaBio                            GmbH', 'Email': 'info@sanabio.bio'}
# {'Name': 'Voelkel Naturkostsäfte                            GmbH', 'Email': 'info@voelkeljuice.de'}
# {'Name': 'Elbtalaue Naturkostprodukte                            GmbH', 'Email': 'info@elbtalaue-naturkostprodukte.de'}
# {'Name': 'bios GmbH                            GmbH', 'Email': 'info@bios.de'}
# {'Name': 'Gut Saunstorf                             gGmbH - Der Klosterladen', 'Email': 'service@derklosterladen.com'}
# {'Name': 'Dr. Taffi Kosmetik Deutschland und Österreich                            e.K.', 'Email': 'info@drtaffi.de'}
# {'Name': 'B.TEALY                            GmbH', 'Email': 'service@b-tealy.de'}
# {'Name': 'No Coffee                            GmbH', 'Email': 'hello@no-coffee.de'}
# {'Name': 'Braaker Mühle Brot- und Backwaren                            GmbH', 'Email': 'baeckerei@braaker-muehle.de'}
# {'Name': 'Worlée NaturProdukte                             GmbH', 'Email': 'naturprodukte@worlee.de'}
# {'Name': 'vinoverde - Bioweinhandel                            Einzelunternehmer', 'Email': 'info@vinoverde.de'}
# {'Name': 'Bäckerei Bahde GmbH                            Produktion und Verkauf von Demeter-Backwaren', 'Email': 'bestellung@bahde.de'}
# {'Name': 'ethiconomy services                            gmbh', 'Email': 'make@bedda-world.com'}
# {'Name': 'Nelsons                            GmbH', 'Email': 'info-de@nelsons.net'}
# {'Name': 'HEJ Natural - Goodlife Company                            GmbH', 'Email': 'hej@hej-natural.de'}
# {'Name': 'Kale&Me                            GmbH', 'Email': 'hallo@kaleandme.de'}
# {'Name': 'Gut Wulksfelde                             GmbH', 'Email': 'info@gut-wulksfelde.de'}
# {'Name': 'MeaVita                            (JMP Service KG)', 'Email': 'info@meavita.de'}
# {'Name': 'Ratsherrn Brauerei GmbH                            GmbH', 'Email': 'info@ratsherrn.de'}
# {'Name': 'EAT SMARTER GmbH & Co. KG                            Verlagswesen', 'Email': 'info@eatsmarter.de'}
# {'Name': 'beckers bester                            GmbH', 'Email': 'info@beckers-bester.de'}
# {'Name': 'schuelke                            GmbH', 'Email': 'info@schuelke.com'}
# {'Name': 'Golconda                            GmbH', 'Email': 'sderosa@golconda.de'}
# {'Name': 'LOGOCOS Naturkosmetik                            AG', 'Email': 'post@logocos.de'}
# {'Name': 'PURYA                            GmbH', 'Email': 'info@purya.de'}
# {'Name': 'Kornkiste - Unverpackt-Online                            Einzelunternehmer', 'Email': 'kornkiste@gmail.com'}
# {'Name': 'TOFU Manufaktur Christian Nagel GmbH                            GmbH', 'Email': 'kontakt@tofunagel.de'}
# {'Name': 'Eat like Eve                            e.K.', 'Email': 'post@eat-like-eve.de'}
# {'Name': 'Küstentee                            e. K.', 'Email': 'info@kuestentee.de'}
# {'Name': 'Gebrüder Ewald                             GmbH', 'Email': 'info@ueberwood.eu'}
# {'Name': 'Ölmühle Solling                            GmbH', 'Email': 'info@oelmuehle-solling.de'}
# {'Name': 'natürlich lang leben                            UG', 'Email': 'info@natuerlichlangleben.de'}
# {'Name': 'Bremer Gewürzhandel                            GmbH', 'Email': 'info@bremer-gewuerzhandel.de'}
# {'Name': 'Liebesgut Tiernahrungs GmbH & Co. OHG                            GmbH & Co. OHG', 'Email': 'kontakt@liebesgut-tiernahrung.de'}
# {'Name': 'CBD-Infos.com                            Einzelunternehmen', 'Email': 'hallo@cbd-infos.com'}
# {'Name': 'Bionatic                            GmbH & Co. KG', 'Email': 'greenbox@bionatic.de'}
# {'Name': 'EXVital                            GmbH', 'Email': 'community@exvital.de'}
# {'Name': 'Essento Insect Food                            GmbH', 'Email': 'hallo@essento.eu'}
# {'Name': 'VIVANI Bioschokolade                            GmbH', 'Email': 'info@vivani.de'}
# {'Name': 'EcoFinia                             GmbH', 'Email': 'info@ecofinia.de'}
# {'Name': 'herzberger bäckerei                            GmbH', 'Email': 'info@herzberger.com'}
# {'Name': 'KEIKO Shimodozono International                             GmbH', 'Email': 'info@keiko.de'}
# {'Name': 'jomu                            BIO Gesundheitsprodukte', 'Email': 'info@gerstengras-natur.de'}
# {'Name': 'Kumaio Selecto                            @ H&T Feinkost GmbH', 'Email': 'hello@kumaio-selecto.de'}
# {'Name': 'AVE – Absolute Vegan Empire                            GmbH & Co. KG', 'Email': 'info@ave.vg'}
# {'Name': 'Löwenanteil                            GmbH', 'Email': 'thomas@loewenanteil.com'}
# {'Name': 'vekoop                            GmbH', 'Email': 'info@vekoop.de'}
# {'Name': 'Betty Butter                            GmbH', 'Email': 'mail@bettybutter.de'}
# {'Name': 'Dr. C. SOLDAN                            GmbH', 'Email': 'kundenservice@soldan.com'}
# {'Name': 'Kräuterladen.com                             UG & CO. KG', 'Email': 'info@vollzucker.de'}
# {'Name': 'RAWBITE                            ApS', 'Email': 'info@rawbite.com'}
# {'Name': 'saftgras                            GmbH', 'Email': 'info@saftgras.de'}
# {'Name': 'Eisblümerl Naturkost                            GmbH', 'Email': 'info@eisbluemerl.de'}
# {'Name': 'Freude am Genuss                            GmbH', 'Email': 'info@gewuerz-glueck.com'}
# {'Name': 'tesano bio                            UG (haftungsbeschränkt)', 'Email': 'info@tesanobio.de'}
# {'Name': 'Trinity Food                            Einzelunternehmen', 'Email': 'info@trinity-food.de'}
# {'Name': 'Neumarkter Lammsbräu Gebr. Ehrnsperger                            KG', 'Email': 'info@lammsbraeu.de'}
# {'Name': 'Georg Thalhammer - Handel mit Bio-Lebensmitteln                            e.K.', 'Email': 'info@georgthalhammer.com'}
# {'Name': 'ayurvedaben                            (Einzelunternehmen)', 'Email': 'anfragen@ayurvedaben.com'}
# {'Name': "Jalall D'or                            GmbH", 'Email': 'info@jalalldor.de'}
# {'Name': 'Natural Self                             KU', 'Email': 'info@natural-self.de'}
# {'Name': 'Purabyo                            GmbH', 'Email': 'hello@purabyo.de'}
# {'Name': 'Destillerie Dwersteg                            GmbH & Co. KG', 'Email': 'info@dwersteg.de'}
# {'Name': 'knuspur                            e.K:', 'Email': 'business@knuspur.eu'}
# {'Name': 'Hassia Mineralquellen GmbH&Co.KG                            GmbH&Co.KG', 'Email': 'kundenservice@hassia-gruppe.com'}
# {'Name': 'UEBE Medical                            GmbH', 'Email': 'info@cyclotest.de'}
# {'Name': 'MASMI ORGANIC CARE                            Health & Care', 'Email': 'post@masmi-organic-care.com'}
# {'Name': 'Andros SO GOOD So Veggie                            Andros Deutschland GmbH', 'Email': 'info@andros.de'}
# {'Name': 'Rebional                             GmbH', 'Email': 'info@rebional.de'}
# {'Name': 'Unverträglichkeitsladen                            Tobias Höhne Einzelunternehmer', 'Email': 'Info@unvertraeglichkeitsladen.de'}
# {'Name': '858 Handels                             GmbH', 'Email': 'service@matcha-karu.com'}
# {'Name': 'Organic Garden                            AG', 'Email': 'info@organicgarden.de'}
# {'Name': 'FRUTEG                            GmbH', 'Email': 'info@fruteg.de'}
# {'Name': 'BTK Bio-Tierkost                            GmbH', 'Email': 'service@bio-tierkost.de'}
# {'Name': 'Tetra Pak                             GmbH @ Co KG', 'Email': 'tphinfo@tetrapak.com'}
# {'Name': 'Transgourmet Deutschland                            GmbH & Co. OHG', 'Email': 'kontakt@transgourmet.de'}
# {'Name': 'TERRA KAHWA Deutschland                            UG (haftungsbeschränkt)', 'Email': 'info@terra-kahwa.de'}
# {'Name': 'Pottsalat                            GmbH', 'Email': 'kontakt@pottsalat.de'}
# {'Name': 'Bienenwixe', 'Email': 'info@bienenwixe.de'}
# {'Name': 'D-Felderzeugnisse                             GmbH', 'Email': 'service@defu.de'}
# {'Name': 'Demeter-Felderzeugnisse                            GmbH', 'Email': 'demeter@felderzeugnisse.de'}
# {'Name': 'GEPA - The Fair Trade Company                            GmbH', 'Email': 'info@gepa.de'}
# {'Name': 'Matchachin - Tausendkraut                            GmbH', 'Email': 'energy@matchachin.com'}
# {'Name': 'BULLDOG                             Hautpflege', 'Email': 'hello@bulldoghautpflege.com'}
# {'Name': 'Biovegan                            GmbH', 'Email': 'info@biovegan.de'}
# {'Name': 'Grönaverde - ALPiNOFiT                            GmbH', 'Email': 'servus@alpinofit.de'}
# {'Name': 'GÍÍLINEA BÍO                            KG', 'Email': 'office@giilinea.com'}
# {'Name': 'ORBIMED Meine Mundgesunde                            Personengesellschaft', 'Email': 'info@orbimed.de'}
# {'Name': 'Pilze Wohlrab                            GmbH & Co. KG', 'Email': 'bestellung@vitalpilze-naturheilkraft.de'}
# {'Name': 'Ökokiste                            e.V.', 'Email': 'info@oekokiste.de'}
# {'Name': 'Bärbel Drexel                            GmbH', 'Email': 'service@baerbel-drexel.de'}
# {'Name': 'Happy Coffee                             GmbH', 'Email': 'support@happycoffee.org'}
# {'Name': 'CBDNOL                            GmbH', 'Email': 'info@cbdnol.com'}
# {'Name': 'Wirtz Wellness Produkte                            Einzelunternehmen', 'Email': 'info@wirtzwellnessprodukte.de'}
# {'Name': 'Wild Baboon                            GmbH', 'Email': 'kontakt@wildbaboon.de'}
# {'Name': 'Haus Rabenhorst                             GmbH & Co. KG', 'Email': 'info@haus-rabenhorst.de'}
# {'Name': 'meine ernte                            GbR', 'Email': 'info@meine-ernte.de'}
# {'Name': 'Byodo Naturkost                            GmbH', 'Email': 'info@byodo.de'}
# {'Name': 'Veggie Specials                            Einzelunternehmen', 'Email': 'info@veggie-specials.com'}
# {'Name': 'Sleepful Wellness                            UG', 'Email': 'domink@sleepful.de'}
# {'Name': 'PLANT BASED POWER                            GmbH', 'Email': 'hello@feel-food.com'}
# {'Name': 'Kräutermax                            GmbH & Co KG', 'Email': 'shop@kraeutermax.at'}
# {'Name': 'Wellnessel                            UG (haftungsbeschränkt)', 'Email': 'info@wellnessel.com'}
# {'Name': 'mehr-gruen.de                            Einzelunternehmen', 'Email': 'kontakt@mehr-gruen.de'}
# {'Name': 'Trinkkost                            GmbH', 'Email': 'support@trinkkost.de'}
# {'Name': 'MADENA                            GmbH & Co. KG', 'Email': 'info@madena-kg.de'}
# {'Name': 'RohKöstlich                            GmbH', 'Email': 'info@rohkoestlich.com'}
# {'Name': 'Fair Karma                             GmbH', 'Email': 'info@fairkarma.de'}
# {'Name': 'FAIR SQUARED                            GmbH', 'Email': 'info@fairsquared.info'}
# {'Name': 'Karl-Otto Werz Naturkornmühle                            GmbH & Co. KG', 'Email': 'vollwert@werz.bio'}
# {'Name': 'PAULkocht                            gGmbH', 'Email': 'info@paul-kocht.de'}
# {'Name': 'Karapatzakis Aristos Olivenöl                            GbR', 'Email': 'kontakt@aristos-olivenoel.de'}
# {'Name': 'Green Cola Germany                            GmbH', 'Email': 'marketing@greencolagermany.de'}
# {'Name': 'Laetitia Naturprodukte                            Dr. C. SOLDAN Natur- und Gesundheitsprodukte GmbH', 'Email': 'info@bitterstern.de'}
# {'Name': 'Naturata                            AG', 'Email': 'kontakt@naturata.de'}
# {'Name': 'Little Lunch                            GmbH', 'Email': 'support@littlelunch.de'}
# {'Name': 'SALUVegan                            -', 'Email': 'info@saluvegan.com'}
# {'Name': 'Miko Kaffee                            GmbH', 'Email': 'vertrieb@mikokaffee.de'}
# {'Name': 'drinkitnow                            GmbH', 'Email': 'rose@drinkitnow.de'}
# {'Name': 'completeorganics                            GmbH', 'Email': 'hi@completeorganics.de'}
# {'Name': 'THE DUKE Destillerie                            - Einzelunternehmen', 'Email': 'info@theduke-gin.de'}
# {'Name': 'everdry                            GmbH & Co. KG', 'Email': 'info@everdry.de'}
# {'Name': 'Buah                             GmbH', 'Email': 'info@buah.de'}
# {'Name': 'Beutelsbacher Fruchtsaftkelterei                            GmbH', 'Email': 'info@beutelsbacher.de'}
# {'Name': 'sana essence                            GmbH', 'Email': 'info@sana-essence.de'}
# {'Name': 'GUATAVITA - Panela by Meisel Fine Goods GmbH                            GmbH', 'Email': 'hola@guatavita.de'}
# {'Name': 'vitalundfitmit100                            GmbH', 'Email': 'info@vitalundfitmit100.de'}
# {'Name': 'SUVO                            Einzelfirma Susanne Vogel', 'Email': 'info@suvovital.com'}
# {'Name': 'Vita Et Natura                            GmbH', 'Email': 'info@vitaetnatura.com'}
# {'Name': 'JARFOOD                            GmbH', 'Email': 'support@jarmino.de'}
# {'Name': 'etepetete                            GmbH', 'Email': 'kundensupport@etepetete-bio.de'}
# {'Name': 'Kraftmischer                            GmbH', 'Email': 'info@kraftmischer.de'}
# {'Name': 'Hanf im Glück                            GmbH', 'Email': 'kontakt@hanf-im-glueck.shop'}
# {'Name': 'Hevert-Arzneimittel                            GmbH & Co. KG', 'Email': 'info@hevert.de'}
# {'Name': 'I·DO -                             Antidote Vertriebs GmbH', 'Email': 'hallo@ido.bio'}
# {'Name': 'BioProphyl                            GmbH', 'Email': 'info@bioprophyl.de'}
# {'Name': 'Mate de Pantera                            GmbH', 'Email': 'info@matedepantera.de'}
# {'Name': 'Pastazeit                            GesnbR', 'Email': 'office@pastazeit.com'}
# {'Name': 'strick-mir-was.at                            e.U.', 'Email': 'willkommen@strick-mir-was.at'}
# {'Name': 'KRAFTVOLL                            Einzelunternehmen', 'Email': 'frank@kraftvoll-superfoods.de'}
# {'Name': 'reCIRCLE Deutschland                            (Elithro GmbH)', 'Email': 'mitmachen@recircle.de'}
# {'Name': 'livQ                            AG', 'Email': 'info@livq.de'}
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# Cell In[58], line 3
#       1 company_data1 = []
#       2 for link in links1:
# ----> 3     driver = webdriver.Edge()
#       5     # Visit the website
#       6     driver.get(link)
#
# File ~\anaconda3\envs\hello-tf\lib\site-packages\selenium\webdriver\edge\webdriver.py:45, in WebDriver.__init__(self, options, service, keep_alive)
#      42 service = service if service else Service()
#      43 options = options if options else Options()
# ---> 45 super().__init__(
#      46     DesiredCapabilities.EDGE["browserName"],
#      47     "ms",
#      48     options,
#      49     service,
#      50     keep_alive,
#      51 )
#
# File ~\anaconda3\envs\hello-tf\lib\site-packages\selenium\webdriver\chromium\webdriver.py:56, in ChromiumDriver.__init__(self, browser_name, vendor_prefix, options, service, keep_alive)
#      53 self.service.start()
#      55 try:
# ---> 56     super().__init__(
#      57         command_executor=ChromiumRemoteConnection(
#      58             remote_server_addr=self.service.service_url,
#      59             browser_name=browser_name,
#      60             vendor_prefix=vendor_prefix,
#      61             keep_alive=keep_alive,
#      62             ignore_proxy=options._ignore_local_proxy,
#      63         ),
#      64         options=options,
#      65     )
#      66 except Exception:
#      67     self.quit()
#
# File ~\anaconda3\envs\hello-tf\lib\site-packages\selenium\webdriver\remote\webdriver.py:206, in WebDriver.__init__(self, command_executor, keep_alive, file_detector, options)
#     204 self._authenticator_id = None
#     205 self.start_client()
# --> 206 self.start_session(capabilities)
#
# File ~\anaconda3\envs\hello-tf\lib\site-packages\selenium\webdriver\remote\webdriver.py:290, in WebDriver.start_session(self, capabilities)
#     283 """Creates a new session with the desired capabilities.
#     284
#     285 :Args:
#     286  - capabilities - a capabilities dict to start the session with.
#     287 """
#     289 caps = _create_caps(capabilities)
# --> 290 response = self.execute(Command.NEW_SESSION, caps)["value"]
#     291 self.session_id = response.get("sessionId")
#     292 self.caps = response.get("capabilities")
#
# File ~\anaconda3\envs\hello-tf\lib\site-packages\selenium\webdriver\remote\webdriver.py:345, in WebDriver.execute(self, driver_command, params)
#     343 response = self.command_executor.execute(driver_command, params)
#     344 if response:
# --> 345     self.error_handler.check_response(response)
#     346     response["value"] = self._unwrap_value(response.get("value", None))
#     347     return response
#
# File ~\anaconda3\envs\hello-tf\lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# SessionNotCreatedException: Message: session not created
# from no such execution context: loader has changed while resolving nodes
#   (Session info: MicrosoftEdge=115.0.1901.200)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00007FF6B26F5422+69586]
# 	Microsoft::Applications::Events::EventProperty::~EventProperty [0x00007FF6B2685662+760226]
# 	(No symbol) [0x00007FF6B243B8CC]
# 	(No symbol) [0x00007FF6B243F7FE]
# 	(No symbol) [0x00007FF6B244282D]
# 	(No symbol) [0x00007FF6B2442920]
# 	(No symbol) [0x00007FF6B24AC71F]
# 	(No symbol) [0x00007FF6B24A2B83]
# 	(No symbol) [0x00007FF6B247589E]
# 	(No symbol) [0x00007FF6B2474B6B]
# 	(No symbol) [0x00007FF6B2476024]
# 	Microsoft::Applications::Events::ILogManager::DispatchEventBroadcast [0x00007FF6B28CD229+1294553]
# 	(No symbol) [0x00007FF6B24F49F4]
# 	Microsoft::Applications::Events::EventProperty::~EventProperty [0x00007FF6B25D3DF1+33073]
# 	Microsoft::Applications::Events::EventProperty::~EventProperty [0x00007FF6B25CC409+1865]
# 	Microsoft::Applications::Events::ILogManager::DispatchEventBroadcast [0x00007FF6B28CBE01+1289393]
# 	Microsoft::Applications::Events::ILogConfiguration::operator* [0x00007FF6B268DC68+20184]
# 	Microsoft::Applications::Events::ILogConfiguration::operator* [0x00007FF6B268A2F4+5476]
# 	Microsoft::Applications::Events::ILogConfiguration::operator* [0x00007FF6B268A3EC+5724]
# 	Microsoft::Applications::Events::EventProperty::~EventProperty [0x00007FF6B267ECA1+733153]
# 	BaseThreadInitThunk [0x00007FFDA4C07604+20]
# 	RtlUserThreadStart [0x00007FFDA55A26A1+33]

# %%
len(company_data1)
# Out:
# 206

# %%
data1 = pd.DataFrame(company_data1)

# %%
data1
# Out:
#                                                   Name  \
# 0    riva Systemtechnik                            ...
# 1       STRAYZ Petfood                            GmbH
# 2           niceshops                             GmbH
# 3    CONTIGO Fairtrade                            GmbH
# 4    BWT Sports & Digital Services                 ...
# ..                                                 ...
# 201        Pastazeit                            GesnbR
# 202  strick-mir-was.at                            e.U.
# 203  KRAFTVOLL                            Einzelunt...
# 204  reCIRCLE Deutschland                          ...
# 205                 livQ                            AG
#
#                              Email
# 0              info@riva-filter.de
# 1                   info@strayz.de
# 2            office@ecco-verde.com
# 3                  info@contigo.de
# 4                     news@bwt.com
# ..                             ...
# 201           office@pastazeit.com
# 202   willkommen@strick-mir-was.at
# 203  frank@kraftvoll-superfoods.de
# 204          mitmachen@recircle.de
# 205                   info@livq.de
#
# [206 rows x 2 columns]

# %%
links2=links1[207:218]

# %%
links2
# Out:
# ['https://www.lifeverde.de/gruene-unternehmen/nachhaltige-ernaehrung-u-gesundheit/feelgood-shop',
#  'https://www.lifeverde.de/gruene-unternehmen/nachhaltige-ernaehrung-u-gesundheit/erdschwalbe-thomas-zimmermann',
#  'https://www.lifeverde.de/gruene-unternehmen/nachhaltige-ernaehrung-u-gesundheit/niehoffs-vaihinger-fruchtsaft',
#  'https://www.lifeverde.de/gruene-unternehmen/nachhaltige-ernaehrung-u-gesundheit/opw-ingredients',
#  'https://www.lifeverde.de/gruene-unternehmen/nachhaltige-ernaehrung-u-gesundheit/greensmile',
#  'https://www.lifeverde.de/gruene-unternehmen/nachhaltige-ernaehrung-u-gesundheit/organic-veggie-food',
#  'https://www.lifeverde.de/gruene-unternehmen/nachhaltige-ernaehrung-u-gesundheit/signature-products',
#  'https://www.lifeverde.de/gruene-unternehmen/nachhaltige-ernaehrung-u-gesundheit/nordic-trading-group',
#  'https://www.lifeverde.de/gruene-unternehmen/nachhaltige-ernaehrung-u-gesundheit/pure-haircare-lifestyle-brands',
#  'https://www.lifeverde.de/gruene-unternehmen/nachhaltige-ernaehrung-u-gesundheit/1616-pfaffmann']

# %%
company_data2 = []
for link in links2:
    driver = webdriver.Edge()

    # Visit the website
    driver.get(link)

    # Get the page source code after the website has fully loaded
    html = driver.page_source

    # Close the browser
    driver.quit()

    # Parse the HTML using BeautifulSoup
    soup = BeautifulSoup(html, "html.parser")

    # Find the name and email within the div with class "adressbox"
    adressbox_div = soup.find("div", class_="adressbox")

    # Find the name within the adressbox div
    name_element = adressbox_div.find("strong")
    name = name_element.text.strip() if name_element else "Name not found"

    # Find the email within the adressbox div
    email_element = adressbox_div.find("a")
    email = email_element.text.strip() if email_element else "Email not found"
    
    data = {}
    data['Name'] = name
    data['Email'] = email
    company_data2.append(data)

    print(data)
# Out:
# {'Name': 'Feelgood Shop                            B.V.', 'Email': 'info@feelgood-shop.com'}
# {'Name': 'Erdschwalbe - Thomas Zimmermann                            Einzelunternehmen', 'Email': 'info@erdschwalbe.de'}
# {'Name': 'Niehoffs Vaihinger Fruchtsaft                            GmbH', 'Email': 'info@nvf-marken.de'}
# {'Name': 'OPW Ingredients                            GmbH', 'Email': 'info@opw-ingredients.com'}
# {'Name': 'GreenSmile                            GmbH', 'Email': 'office@mysalifree.com'}
# {'Name': 'organic veggie food                            GmbH', 'Email': 'info@soto.de'}
# {'Name': 'Signature Products                            GmbH', 'Email': 'info@signature-products.com'}
# {'Name': 'Nordic Trading Group                            BV', 'Email': 'info@nordicoil.de'}
# {'Name': 'Pure Haircare - Lifestyle Brands                            GmbH', 'Email': 'office@purehaircare.at'}
# {'Name': '1616 Pfaffmann                            Einzelunternehmen', 'Email': 'info@pfaffmann-wein.de'}

# %%
data2 = pd.DataFrame(company_data2)

# %%
data2
# Out:
#                                                 Name  \
# 0      Feelgood Shop                            B.V.
# 1  Erdschwalbe - Thomas Zimmermann               ...
# 2  Niehoffs Vaihinger Fruchtsaft                 ...
# 3    OPW Ingredients                            GmbH
# 4         GreenSmile                            GmbH
# 5  organic veggie food                           ...
# 6  Signature Products                            ...
# 7  Nordic Trading Group                          ...
# 8  Pure Haircare - Lifestyle Brands              ...
# 9  1616 Pfaffmann                            Einz...
#
#                          Email
# 0       info@feelgood-shop.com
# 1          info@erdschwalbe.de
# 2           info@nvf-marken.de
# 3     info@opw-ingredients.com
# 4        office@mysalifree.com
# 5                 info@soto.de
# 6  info@signature-products.com
# 7            info@nordicoil.de
# 8       office@purehaircare.at
# 9       info@pfaffmann-wein.de

# %%
Company=pd.concat([data,data1,data2],axis=0)

# %%
Company
# Out:
#                                                  Name  \
# 0   CBDwelt.de der Endower                        ...
# 1   EASYFITNESS Franchise                         ...
# 2   ganio.de                            Einzelunte...
# 3   Eine Marke der Centerboard Holdings           ...
# 4   This Is Vegan - Plantbased Lifestyle Magazin  ...
# ..                                                ...
# 5   organic veggie food                           ...
# 6   Signature Products                            ...
# 7   Nordic Trading Group                          ...
# 8   Pure Haircare - Lifestyle Brands              ...
# 9   1616 Pfaffmann                            Einz...
#
#                           Email
# 0               info@cbdwelt.de
# 1         info@easyfitness.club
# 2                 info@ganio.de
# 3           service@herbano.com
# 4        info@this-is-vegan.com
# ..                          ...
# 5                  info@soto.de
# 6   info@signature-products.com
# 7             info@nordicoil.de
# 8        office@purehaircare.at
# 9        info@pfaffmann-wein.de
#
# [358 rows x 2 columns]

# %%
Company = Company.reset_index(drop=True)

# %%
Company
# Out:
#                                                   Name  \
# 0    CBDwelt.de der Endower                        ...
# 1    EASYFITNESS Franchise                         ...
# 2    ganio.de                            Einzelunte...
# 3    Eine Marke der Centerboard Holdings           ...
# 4    This Is Vegan - Plantbased Lifestyle Magazin  ...
# ..                                                 ...
# 353  organic veggie food                           ...
# 354  Signature Products                            ...
# 355  Nordic Trading Group                          ...
# 356  Pure Haircare - Lifestyle Brands              ...
# 357  1616 Pfaffmann                            Einz...
#
#                            Email
# 0                info@cbdwelt.de
# 1          info@easyfitness.club
# 2                  info@ganio.de
# 3            service@herbano.com
# 4         info@this-is-vegan.com
# ..                           ...
# 353                 info@soto.de
# 354  info@signature-products.com
# 355            info@nordicoil.de
# 356       office@purehaircare.at
# 357       info@pfaffmann-wein.de
#
# [358 rows x 2 columns]

# %%
Company.to_csv('Company.csv')

# %%
df=pd.read_csv('Company.csv')
df1=pd.read_csv('Company1.csv')
df2=pd.read_csv('Company2.csv')

# %%
Company_data=pd.concat([df,df1,df2],axis=0)

# %%
Company_data = Company_data.reset_index(drop=True)

# %%
Company_data.drop('Unnamed: 0',axis=1,inplace=True)

# %%
Company_data
# Out:
#                                                   Name  \
# 0    CBDwelt.de der Endower                        ...
# 1    EASYFITNESS Franchise                         ...
# 2    ganio.de                            Einzelunte...
# 3    Eine Marke der Centerboard Holdings           ...
# 4    This Is Vegan - Plantbased Lifestyle Magazin  ...
# ..                                                 ...
# 750  Coa Coa / Ursula Piber & Ines Häfner          ...
# 751  zündstoff - fair organic clothing             ...
# 752             Laimer                            GmbH
# 753  Edeltruhe                            - kreativ...
# 754                     Korkeria | Aus Kork. Für Dich.
#
#                            Email
# 0                info@cbdwelt.de
# 1          info@easyfitness.club
# 2                  info@ganio.de
# 3            service@herbano.com
# 4         info@this-is-vegan.com
# ..                           ...
# 750              ines@coagoa.com
# 751  info@zuendstoff-clothing.de
# 752               info@laimer.bz
# 753       edeltruhe@edeltruhe.de
# 754             shop@korkeria.ch
#
# [755 rows x 2 columns]

# %%
# Replace space with comma
Company_data['Name'] = Company_data['Name'].replace('\s+', ' ', regex=True)

# %%
Company_data['Name']
# Out:
# 0                            CBDwelt.de der Endower GmbH
# 1                             EASYFITNESS Franchise GmbH
# 2                             ganio.de Einzelunternehmen
# 3      Eine Marke der Centerboard Holdings Incorporation
# 4      This Is Vegan - Plantbased Lifestyle Magazin E...
#                              ...
# 750             Coa Coa / Ursula Piber & Ines Häfner GbR
# 751                zündstoff - fair organic clothing GbR
# 752                                          Laimer GmbH
# 753                  Edeltruhe - kreativ und individuell
# 754                       Korkeria | Aus Kork. Für Dich.
# Name: Name, Length: 755, dtype: object

# %%
Company_data.to_csv('Company_data.csv')
